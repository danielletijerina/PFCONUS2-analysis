# %% [markdown]
# ### Compute Total Water Storage from PFCLM outputs
#
# DTT 10/2022
#
# **PFTools Python**:
# (with daily averages)
# `TWS = SUBstorage + SURFstorage + SWEstorage`
#
# _____
#
# This script takes already postprocessed PFCLM outputs as PFB files and computes the daily, (monthly, and yearly) averages to be saved as PFB files.
#
# Inputs:
# - Directory where PFCLM daily averages are and directory where you want to save output (these should be the same)
# - Hourly PFB files of **subsurface storage [m^3]**, **surface water storage [m^3],** and CLM **Snow Water Equivalent [mm]** outputs
# - Water year and day start/end
#
# Outputs:
# - PFB files for daily average Total Water Storage in [m^3]
# - _PFB files for monthly average Total Water Storage in [m^3] (NOT IMPLEMENTED YET)_
# - PFB files for yearly average Total Water Storage in [m^3]
#
# User Notes:
# - Because the daily files are read in here and have already been corrected for the CONUS timezone, no adjustments here are necessary
# - Make sure to check units of your input files! (see the Inputs list ^)
#
# DTT Notes (10/26/22):
# - Need to add in MONTHLY averages

# %%
import numpy as np
from parflow import Run
import sys
from parflow.tools.io import read_pfb,write_pfb
import parflow.tools.hydrology as hydro

# %%
#these 3 entries (year, day start and day end) will eventually be argv to the script so that it can be run from bash script
water_year = 1999
day_start = 0 #day_start = 0 is the first day of the water year, Oct 1 (e.g., day_start = 2 starts at hour 49)
day_end = 365 #day_end = 365 is the final day of the water year, Sept 30

# water_year = int(sys.argv[1])
# day_start = int(sys.argv[1])
# day_end = int(sys.argv[1])

# directory to save averages to
#directory_out = f'/glade/scratch/tijerina/CONUS2/spinup_WY2003/averages'
directory_out = '/home/dtt2/CONUS2/analysis_scripts/Taylor_test_outputs'

####### TAYLOR ########

nz = 5 #10
ny = 47 #3256
nx = 45 #4442

dx = 1000
dy = 1000
dz = 5 # 200

# apparently it's good to use high numbers when saving files to speed up reading?
# for write_pfb function
p = 5 #72
q = 5 #48
r = 1

# %%
# Initialize arrays for daily, monthly, yearly TWS
tws = np.zeros((ny,nx))
tws_m = np.zeros((ny,nx))
tws_y = np.zeros((ny,nx))

for day in range(day_start+1,day_end+1): 
    
    timestamp_day = str(int(day)).rjust(3, '0')
    print(f'Reading storage from day {timestamp_day}')
    
    
    # Read in Subsurface Storage PFBs (5 layers)
    sub_storage_pfb = read_pfb(f'{directory_out}/SUBstorage.{water_year}.daily.{timestamp_day}.pfb')
    # sum all layers of subsurface storage
    sub_storage_sum = np.sum(sub_storage_pfb, axis = 0)

    
    # Read in Surface Storage PFBs 
    surf_storage_pfb = np.squeeze(read_pfb(f'{directory_out}/SURF_WATstorage.{water_year}.daily.{timestamp_day}.pfb'))

    
    # Read in SWE PFBs
    swe_pfb =  np.squeeze(read_pfb(f'{directory_out}/swe_out.{water_year}.daily.{timestamp_day}.pfb'))
    # SWE is in mm, so convert to m^3 for consistent units and storage factor
    swe_meters = swe_pfb * 1000 * dx*dy 

    
    # Calculate Total Water Storage
    tws = sub_storage_sum + surf_storage_pfb + swe_meters
    # save daily TWS PFB
    write_pfb(f'{directory_out}/TWS.{water_year}.daily.{timestamp_day}.pfb',tws,dx=dx,dy=dy,dz=dz,P=p,Q=q,R=r,dist=False)
    
    tws_sum = np.sum(tws)
    write_pfb(f'{directory_out}/TWS_DOMAIN_TOTAL.{water_year}.daily.{timestamp_day}.pfb',tws,dx=dx,dy=dy,dz=dz,P=p,Q=q,R=r,dist=False)
    # monthly TWS
    
    
    # yearly TWS 
    if (day_end-day_start) == 365:
        tws_y += tws / 365
    else:
        print(f'You do not have a full year of daily files, so yearly average will not be calculated!')
        

# save yearly TWS PFB
if (day_end-day_start) == 365:
    write_pfb(f'{directory_out}/TWS.{water_year}.yearly.pfb',tws_y,dx=dx,dy=dy,dz=dz,P=p,Q=q,R=r,dist=False)
# Out:
# Reading storage from day 001
# Reading storage from day 002
# Reading storage from day 003
# Reading storage from day 004
# Reading storage from day 005
# Reading storage from day 006
# Reading storage from day 007
# Reading storage from day 008
# Reading storage from day 009
# Reading storage from day 010
# Reading storage from day 011
# Reading storage from day 012
# Reading storage from day 013
# Reading storage from day 014
# Reading storage from day 015
# Reading storage from day 016
# Reading storage from day 017
# Reading storage from day 018
# Reading storage from day 019
# Reading storage from day 020
# Reading storage from day 021
# Reading storage from day 022
# Reading storage from day 023
# Reading storage from day 024
# Reading storage from day 025
# Reading storage from day 026
# Reading storage from day 027
# Reading storage from day 028
# Reading storage from day 029
# Reading storage from day 030
# Reading storage from day 031
# Reading storage from day 032
# Reading storage from day 033
# Reading storage from day 034
# Reading storage from day 035
# Reading storage from day 036
# Reading storage from day 037
# Reading storage from day 038
# Reading storage from day 039
# Reading storage from day 040
# Reading storage from day 041
# Reading storage from day 042
# Reading storage from day 043
# Reading storage from day 044
# Reading storage from day 045
# Reading storage from day 046
# Reading storage from day 047
# Reading storage from day 048
# Reading storage from day 049
# Reading storage from day 050
# Reading storage from day 051
# Reading storage from day 052
# Reading storage from day 053
# Reading storage from day 054
# Reading storage from day 055
# Reading storage from day 056
# Reading storage from day 057
# Reading storage from day 058
# Reading storage from day 059
# Reading storage from day 060
# Reading storage from day 061
# Reading storage from day 062
# Reading storage from day 063
# Reading storage from day 064
# Reading storage from day 065
# Reading storage from day 066
# Reading storage from day 067
# Reading storage from day 068
# Reading storage from day 069
# Reading storage from day 070
# Reading storage from day 071
# Reading storage from day 072
# Reading storage from day 073
# Reading storage from day 074
# Reading storage from day 075
# Reading storage from day 076
# Reading storage from day 077
# Reading storage from day 078
# Reading storage from day 079
# Reading storage from day 080
# Reading storage from day 081
# Reading storage from day 082
# Reading storage from day 083
# Reading storage from day 084
# Reading storage from day 085
# Reading storage from day 086
# Reading storage from day 087
# Reading storage from day 088
# Reading storage from day 089
# Reading storage from day 090
# Reading storage from day 091
# Reading storage from day 092
# Reading storage from day 093
# Reading storage from day 094
# Reading storage from day 095
# Reading storage from day 096
# Reading storage from day 097
# Reading storage from day 098
# Reading storage from day 099
# Reading storage from day 100
# Reading storage from day 101
# Reading storage from day 102
# Reading storage from day 103
# Reading storage from day 104
# Reading storage from day 105
# Reading storage from day 106
# Reading storage from day 107
# Reading storage from day 108
# Reading storage from day 109
# Reading storage from day 110
# Reading storage from day 111
# Reading storage from day 112
# Reading storage from day 113
# Reading storage from day 114
# Reading storage from day 115
# Reading storage from day 116
# Reading storage from day 117
# Reading storage from day 118
# Reading storage from day 119
# Reading storage from day 120
# Reading storage from day 121
# Reading storage from day 122
# Reading storage from day 123
# Reading storage from day 124
# Reading storage from day 125
# Reading storage from day 126
# Reading storage from day 127
# Reading storage from day 128
# Reading storage from day 129
# Reading storage from day 130
# Reading storage from day 131
# Reading storage from day 132
# Reading storage from day 133
# Reading storage from day 134
# Reading storage from day 135
# Reading storage from day 136
# Reading storage from day 137
# Reading storage from day 138
# Reading storage from day 139
# Reading storage from day 140
# Reading storage from day 141
# Reading storage from day 142
# Reading storage from day 143
# Reading storage from day 144
# Reading storage from day 145
# Reading storage from day 146
# Reading storage from day 147
# Reading storage from day 148
# Reading storage from day 149
# Reading storage from day 150
# Reading storage from day 151
# Reading storage from day 152
# Reading storage from day 153
# Reading storage from day 154
# Reading storage from day 155
# Reading storage from day 156
# Reading storage from day 157
# Reading storage from day 158
# Reading storage from day 159
# Reading storage from day 160
# Reading storage from day 161
# Reading storage from day 162
# Reading storage from day 163
# Reading storage from day 164
# Reading storage from day 165
# Reading storage from day 166
# Reading storage from day 167
# Reading storage from day 168
# Reading storage from day 169
# Reading storage from day 170
# Reading storage from day 171
# Reading storage from day 172
# Reading storage from day 173
# Reading storage from day 174
# Reading storage from day 175
# Reading storage from day 176
# Reading storage from day 177
# Reading storage from day 178
# Reading storage from day 179
# Reading storage from day 180
# Reading storage from day 181
# Reading storage from day 182
# Reading storage from day 183
# Reading storage from day 184
# Reading storage from day 185
# Reading storage from day 186
# Reading storage from day 187
# Reading storage from day 188
# Reading storage from day 189
# Reading storage from day 190
# Reading storage from day 191
# Reading storage from day 192
# Reading storage from day 193
# Reading storage from day 194
# Reading storage from day 195
# Reading storage from day 196
# Reading storage from day 197
# Reading storage from day 198
# Reading storage from day 199
# Reading storage from day 200
# Reading storage from day 201
# Reading storage from day 202
# Reading storage from day 203
# Reading storage from day 204
# Reading storage from day 205
# Reading storage from day 206
# Reading storage from day 207
# Reading storage from day 208
# Reading storage from day 209
# Reading storage from day 210
# Reading storage from day 211
# Reading storage from day 212
# Reading storage from day 213
# Reading storage from day 214
# Reading storage from day 215
# Reading storage from day 216
# Reading storage from day 217
# Reading storage from day 218
# Reading storage from day 219
# Reading storage from day 220
# Reading storage from day 221
# Reading storage from day 222
# Reading storage from day 223
# Reading storage from day 224
# Reading storage from day 225
# Reading storage from day 226
# Reading storage from day 227
# Reading storage from day 228
# Reading storage from day 229
# Reading storage from day 230
# Reading storage from day 231
# Reading storage from day 232
# Reading storage from day 233
# Reading storage from day 234
# Reading storage from day 235
# Reading storage from day 236
# Reading storage from day 237
# Reading storage from day 238
# Reading storage from day 239
# Reading storage from day 240
# Reading storage from day 241
# Reading storage from day 242
# Reading storage from day 243
# Reading storage from day 244
# Reading storage from day 245
# Reading storage from day 246
# Reading storage from day 247
# Reading storage from day 248
# Reading storage from day 249
# Reading storage from day 250
# Reading storage from day 251
# Reading storage from day 252
# Reading storage from day 253
# Reading storage from day 254
# Reading storage from day 255
# Reading storage from day 256
# Reading storage from day 257
# Reading storage from day 258
# Reading storage from day 259
# Reading storage from day 260
# Reading storage from day 261
# Reading storage from day 262
# Reading storage from day 263
# Reading storage from day 264
# Reading storage from day 265
# Reading storage from day 266
# Reading storage from day 267
# Reading storage from day 268
# Reading storage from day 269
# Reading storage from day 270
# Reading storage from day 271
# Reading storage from day 272
# Reading storage from day 273
# Reading storage from day 274
# Reading storage from day 275
# Reading storage from day 276
# Reading storage from day 277
# Reading storage from day 278
# Reading storage from day 279
# Reading storage from day 280
# Reading storage from day 281
# Reading storage from day 282
# Reading storage from day 283
# Reading storage from day 284
# Reading storage from day 285
# Reading storage from day 286
# Reading storage from day 287
# Reading storage from day 288
# Reading storage from day 289
# Reading storage from day 290
# Reading storage from day 291
# Reading storage from day 292
# Reading storage from day 293
# Reading storage from day 294
# Reading storage from day 295
# Reading storage from day 296
# Reading storage from day 297
# Reading storage from day 298
# Reading storage from day 299
# Reading storage from day 300
# Reading storage from day 301
# Reading storage from day 302
# Reading storage from day 303
# Reading storage from day 304
# Reading storage from day 305
# Reading storage from day 306
# Reading storage from day 307
# Reading storage from day 308
# Reading storage from day 309
# Reading storage from day 310
# Reading storage from day 311
# Reading storage from day 312
# Reading storage from day 313
# Reading storage from day 314
# Reading storage from day 315
# Reading storage from day 316
# Reading storage from day 317
# Reading storage from day 318
# Reading storage from day 319
# Reading storage from day 320
# Reading storage from day 321
# Reading storage from day 322
# Reading storage from day 323
# Reading storage from day 324
# Reading storage from day 325
# Reading storage from day 326
# Reading storage from day 327
# Reading storage from day 328
# Reading storage from day 329
# Reading storage from day 330
# Reading storage from day 331
# Reading storage from day 332
# Reading storage from day 333
# Reading storage from day 334
# Reading storage from day 335
# Reading storage from day 336
# Reading storage from day 337
# Reading storage from day 338
# Reading storage from day 339
# Reading storage from day 340
# Reading storage from day 341
# Reading storage from day 342
# Reading storage from day 343
# Reading storage from day 344
# Reading storage from day 345
# Reading storage from day 346
# Reading storage from day 347
# Reading storage from day 348
# Reading storage from day 349
# Reading storage from day 350
# Reading storage from day 351
# Reading storage from day 352
# Reading storage from day 353
# Reading storage from day 354
# Reading storage from day 355
# Reading storage from day 356
# Reading storage from day 357
# Reading storage from day 358
# Reading storage from day 359
# Reading storage from day 360
# Reading storage from day 361
# Reading storage from day 362
# Reading storage from day 363
# Reading storage from day 364
# Reading storage from day 365

# %%
tws_sum
# Out:
# -9708990107074048.0

# %%
tws.shape
# Out:
# (47, 45)

# %% [markdown]
# #### Quick check yearly and daily TWS to make sure they are similar magnitudes

# %%
tws[30,30]
# Out:
# 34289857.551114544

# %%
tws_y[30,30]
# Out:
# 34293190.83671028

# %%
x = np.squeeze(read_pfb(f'{directory_out}/TWS.1999.daily.365.pfb'))
x.shape
# Out:
# -9999000000000.0

# %%
np.sum(x)
# Out:
# -9708990107074048.0

# %%
sub_storage_pfb.shape
# Out:
# (5, 47, 45)
