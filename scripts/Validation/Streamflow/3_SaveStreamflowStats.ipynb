# %% [markdown]
# ### Compare CONUS2 and USGS streamflow ###
# DTT, 10/22
#
# This notebook reads in CSVs of CONUS2 daily mean flow [cms] and daily mean USGS flow [cms] and computes comparison statistics. Gages are matched between the two csv's to make sure that we're comparing viable gage locations.
#
# Inputs:
# - CONUS2 daily mean flow csv in [cms] - the output of `Make_CONUS2_streamflow_csv.py`
# - USGS daily mean flow csv in [cms] - the output of `point_obs_CONUS2_Streamflow.ipynb`
# - USGS gage metadata csv - the output of `point_obs_CONUS2_Streamflow.ipynb`
#
# Outputs:
# - Gage summary CSV of statistics
# (bias, relative bias, correlation, Spearman rank, RMSE, NSE, scaled RMSE)
# for CONUS 1.0 simulated streamflow, compared to USGS observations.

# %%
import sys
from parflow.tools.io import read_pfb,write_pfb
import numpy as np
import pandas as pd
import hydroeval as he
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from math import sqrt
from scipy import stats

import matplotlib.pyplot as plt

# %%
water_year = 2003
# Directory containing output csv's from `Make_CONUS2_streamflow_csv.py`
organized_dir = '/glade/p/univ/ucsm0002/CONUS2/Validation/Streamflow/Organized_Daily_Flow'
# Where you want to save plots, etc. to
plot_dir = '/glade/p/univ/ucsm0002/CONUS2/Validation/Streamflow/Figures'

# %% [markdown]
# ### Read CONUS2 & USGS flow

# %%
### read in CONUS2 daily flow matched csv
pfdata = pd.read_csv(f'{organized_dir}/FlowMatch_CONUS2_daily_cms_2003.csv',index_col=['site_id'])
pfdata.head()
# Out:
#           USGS_lat   USGS_lon  x_new_adj  y_new_adj   day 001   day 002  \
# site_id
# 1011000  47.069611 -69.079544       4210       2783  4.339120  3.903565
# 1013500  47.237394 -68.582642       4237       2810  2.607411  2.592114
# 1015800  46.523003 -68.371764       4276       2747  3.538157  3.513982
# 1017000  46.777294 -68.157194       4281       2773  8.474701  8.578840
# 1017550  46.628056 -67.953056       4300       2762  0.000110  0.000000
#
#           day 003   day 004   day 005   day 006  ...    day 022    day 023  \
# site_id                                          ...
# 1011000  3.598231  3.739801  3.472192  2.964904  ...   8.415931   9.427277
# 1013500  2.714427  2.122667  2.426324  1.780095  ...  10.531182  10.841114
# 1015800  3.389648  3.025167  2.979538  2.794375  ...  23.623506  33.084342
# 1017000  8.433320  8.120163  7.786723  7.233890  ...  17.952113  33.277058
# 1017550  0.000000  0.000000  0.000000  0.000000  ...   0.126239   0.077560
#
#            day 024    day 025    day 026    day 027    day 028    day 029  \
# site_id
# 1011000   9.732380  19.499970  22.328073  21.454524  17.873519  15.879472
# 1013500  10.288957  10.600749  12.061306  16.507953  16.798331  14.819481
# 1015800  38.403587  35.184230  30.383635  27.200526  22.780802  20.339741
# 1017000  46.507889  49.141900  53.410219  58.835318  57.151723  53.937779
# 1017550   0.050756   0.034315   0.048476   0.110372   0.062056   0.042434
#
#            day 030    day 031
# site_id
# 1011000  14.244763  12.567175
# 1013500  13.234019  11.639035
# 1015800  18.833875  17.107330
# 1017000  50.008866  44.393264
# 1017550   0.028833   0.021246
#
# [5 rows x 35 columns]

# %%
### NEED TO FIX THE LONGITUDE HERE!
pfdata_no_zeros = pfdata.where(pfdata>0, 0.00000001)
pfdata_no_zeros.head()
# Out:
#           USGS_lat      USGS_lon  x_new_adj  y_new_adj   day 001  \
# site_id
# 1011000  47.069611  1.000000e-08       4210       2783  4.339120
# 1013500  47.237394  1.000000e-08       4237       2810  2.607411
# 1015800  46.523003  1.000000e-08       4276       2747  3.538157
# 1017000  46.777294  1.000000e-08       4281       2773  8.474701
# 1017550  46.628056  1.000000e-08       4300       2762  0.000110
#
#               day 002       day 003       day 004       day 005       day 006  \
# site_id
# 1011000  3.903565e+00  3.598231e+00  3.739801e+00  3.472192e+00  2.964904e+00
# 1013500  2.592114e+00  2.714427e+00  2.122667e+00  2.426324e+00  1.780095e+00
# 1015800  3.513982e+00  3.389648e+00  3.025167e+00  2.979538e+00  2.794375e+00
# 1017000  8.578840e+00  8.433320e+00  8.120163e+00  7.786723e+00  7.233890e+00
# 1017550  1.000000e-08  1.000000e-08  1.000000e-08  1.000000e-08  1.000000e-08
#
#          ...    day 022    day 023    day 024    day 025    day 026  \
# site_id  ...
# 1011000  ...   8.415931   9.427277   9.732380  19.499970  22.328073
# 1013500  ...  10.531182  10.841114  10.288957  10.600749  12.061306
# 1015800  ...  23.623506  33.084342  38.403587  35.184230  30.383635
# 1017000  ...  17.952113  33.277058  46.507889  49.141900  53.410219
# 1017550  ...   0.126239   0.077560   0.050756   0.034315   0.048476
#
#            day 027    day 028    day 029    day 030    day 031
# site_id
# 1011000  21.454524  17.873519  15.879472  14.244763  12.567175
# 1013500  16.507953  16.798331  14.819481  13.234019  11.639035
# 1015800  27.200526  22.780802  20.339741  18.833875  17.107330
# 1017000  58.835318  57.151723  53.937779  50.008866  44.393264
# 1017550   0.110372   0.062056   0.042434   0.028833   0.021246
#
# [5 rows x 35 columns]

# %%
# drop metadata columns, will use them later to make final csv with stats
pf_flow_matched = pfdata_no_zeros.drop(columns=['USGS_lat', 'USGS_lon', 'x_new_adj', 'y_new_adj'])
pf_flow_matched.head()
# Out:
#           day 001       day 002       day 003       day 004       day 005  \
# site_id
# 1011000  4.339120  3.903565e+00  3.598231e+00  3.739801e+00  3.472192e+00
# 1013500  2.607411  2.592114e+00  2.714427e+00  2.122667e+00  2.426324e+00
# 1015800  3.538157  3.513982e+00  3.389648e+00  3.025167e+00  2.979538e+00
# 1017000  8.474701  8.578840e+00  8.433320e+00  8.120163e+00  7.786723e+00
# 1017550  0.000110  1.000000e-08  1.000000e-08  1.000000e-08  1.000000e-08
#
#               day 006       day 007       day 008       day 009       day 010  \
# site_id
# 1011000  2.964904e+00  2.711756e+00  2.519148e+00  2.262331e+00  2.004412e+00
# 1013500  1.780095e+00  1.482548e+00  1.307613e+00  1.202425e+00  1.285236e+00
# 1015800  2.794375e+00  2.514015e+00  2.242985e+00  2.058773e+00  2.187055e+00
# 1017000  7.233890e+00  6.638142e+00  6.070441e+00  5.608575e+00  5.285559e+00
# 1017550  1.000000e-08  1.000000e-08  1.000000e-08  1.000000e-08  1.000000e-08
#
#          ...    day 022    day 023    day 024    day 025    day 026  \
# site_id  ...
# 1011000  ...   8.415931   9.427277   9.732380  19.499970  22.328073
# 1013500  ...  10.531182  10.841114  10.288957  10.600749  12.061306
# 1015800  ...  23.623506  33.084342  38.403587  35.184230  30.383635
# 1017000  ...  17.952113  33.277058  46.507889  49.141900  53.410219
# 1017550  ...   0.126239   0.077560   0.050756   0.034315   0.048476
#
#            day 027    day 028    day 029    day 030    day 031
# site_id
# 1011000  21.454524  17.873519  15.879472  14.244763  12.567175
# 1013500  16.507953  16.798331  14.819481  13.234019  11.639035
# 1015800  27.200526  22.780802  20.339741  18.833875  17.107330
# 1017000  58.835318  57.151723  53.937779  50.008866  44.393264
# 1017550   0.110372   0.062056   0.042434   0.028833   0.021246
#
# [5 rows x 31 columns]

# %%
### read in USGS daily flow matched csv
usgsdata= pd.read_csv(f'{organized_dir}/FlowMatch_USGS_daily_cms_2003.csv',index_col=['site_id']) 
usgsdata.head()
# Out:
#          2002-10-01  2002-10-02  2002-10-03  2002-10-04  2002-10-05  \
# site_id
# 1011000    7.414600    7.386300    6.990100    6.565600     6.36750
# 1013500    3.509200    3.424300    3.169600    3.113000     3.33940
# 1015800    6.707100    6.226000    5.716600    5.377000     5.15060
# 1017000    9.876700    9.367300    8.461700    7.952300     7.81080
# 1017550    0.023772    0.024338    0.020659    0.018395     0.01981
#
#          2002-10-06  2002-10-07  2002-10-08  2002-10-09  2002-10-10  ...  \
# site_id                                                              ...
# 1011000     6.19770    5.744900    5.065700    4.528000    4.414800  ...
# 1013500     2.85830    2.858300    2.631900    2.405500    2.504550  ...
# 1015800     5.03740    4.754400    4.499700    4.160100    4.188400  ...
# 1017000     7.13160    7.046700    6.678800    6.282600    6.282600  ...
# 1017550     0.01981    0.018678    0.018678    0.018961    0.021791  ...
#
#          2002-10-22  2002-10-23  2002-10-24  2002-10-25  2002-10-26  \
# site_id
# 1011000    9.310700     8.57490    8.546600    8.631500    9.820100
# 1013500    5.263800     5.40530    5.660000    5.914700    6.197700
# 1015800   22.300400    19.07420   16.725300   14.914100   13.725500
# 1017000   38.205000    33.39400   28.583000   24.507800   21.762700
# 1017550    0.044997     0.03679    0.036224    0.035092    0.030847
#
#          2002-10-27  2002-10-28  2002-10-29  2002-10-30  2002-10-31
# site_id
# 1011000   12.508600   15.508400    16.52720   15.791400   14.319800
# 1013500    6.990100    7.556100     7.30140    7.188200    7.273100
# 1015800   12.904800   12.848200    13.72550   13.725500   13.074600
# 1017000   20.376000   20.715600    21.79100   21.734400   20.347700
# 1017550    0.041884    0.051789     0.03962    0.031979    0.027451
#
# [5 rows x 31 columns]

# %%
usgsdata_no_zeros = usgsdata.where(usgsdata>0, 0.00000001)
usgsdata_no_zeros.head()
# Out:
#          2002-10-01  2002-10-02  2002-10-03  2002-10-04  2002-10-05  \
# site_id
# 1011000    7.414600    7.386300    6.990100    6.565600     6.36750
# 1013500    3.509200    3.424300    3.169600    3.113000     3.33940
# 1015800    6.707100    6.226000    5.716600    5.377000     5.15060
# 1017000    9.876700    9.367300    8.461700    7.952300     7.81080
# 1017550    0.023772    0.024338    0.020659    0.018395     0.01981
#
#          2002-10-06  2002-10-07  2002-10-08  2002-10-09  2002-10-10  ...  \
# site_id                                                              ...
# 1011000     6.19770    5.744900    5.065700    4.528000    4.414800  ...
# 1013500     2.85830    2.858300    2.631900    2.405500    2.504550  ...
# 1015800     5.03740    4.754400    4.499700    4.160100    4.188400  ...
# 1017000     7.13160    7.046700    6.678800    6.282600    6.282600  ...
# 1017550     0.01981    0.018678    0.018678    0.018961    0.021791  ...
#
#          2002-10-22  2002-10-23  2002-10-24  2002-10-25  2002-10-26  \
# site_id
# 1011000    9.310700     8.57490    8.546600    8.631500    9.820100
# 1013500    5.263800     5.40530    5.660000    5.914700    6.197700
# 1015800   22.300400    19.07420   16.725300   14.914100   13.725500
# 1017000   38.205000    33.39400   28.583000   24.507800   21.762700
# 1017550    0.044997     0.03679    0.036224    0.035092    0.030847
#
#          2002-10-27  2002-10-28  2002-10-29  2002-10-30  2002-10-31
# site_id
# 1011000   12.508600   15.508400    16.52720   15.791400   14.319800
# 1013500    6.990100    7.556100     7.30140    7.188200    7.273100
# 1015800   12.904800   12.848200    13.72550   13.725500   13.074600
# 1017000   20.376000   20.715600    21.79100   21.734400   20.347700
# 1017550    0.041884    0.051789     0.03962    0.031979    0.027451
#
# [5 rows x 31 columns]

# %%
usgs_flow_matched = usgsdata_no_zeros

# %%
### read in USGS streamflow gage metadata for all gages with flow in October AND NWM csv for adjusted lat/long
#NWM_gage_csv = pd.read_csv('/glade/p/univ/ucsm0002/CONUS2/domain_files/NWM_Gage_Adjustments_final.csv')
usgs_gage_metadata = pd.read_csv(f'{organized_dir}/FlowMatch_metadata_2003.csv',index_col=['site_id'])
#usgs_gage_metadata = usgs_gage_metadata.drop(columns=['Unnamed: 0'])
#list(usgs_gage_metadata.columns)
usgs_gage_metadata
# Out:
#               site_type agency  \
# site_id
# 1011000    stream gauge   USGS
# 1013500    stream gauge   USGS
# 1015800    stream gauge   USGS
# 1017000    stream gauge   USGS
# 1017550    stream gauge   USGS
# ...                 ...    ...
# 214657975  stream gauge   USGS
# 242354750  stream gauge   USGS
# 344894205  stream gauge   USGS
# 351706800  stream gauge   USGS
# 423205010  stream gauge   USGS
#
#                                                    site_name  site_id_agency  \
# site_id
# 1011000                  Allagash River near Allagash, Maine         1011000
# 1013500                     Fish River near Fort Kent, Maine         1013500
# 1015800                 Aroostook River near Masardis, Maine         1015800
# 1017000                   Aroostook River at Washburn, Maine         1017000
# 1017550                       Williams Brook at Phair, Maine         1017550
# ...                                                      ...             ...
# 214657975            IRVINS CREEK AT SR3168 NR CHARLOTTE, NC       214657975
# 242354750  CAHABA VALLEY CREEK AT CROSS CR RD AT PELHAM, AL.       242354750
# 344894205     NORTH FORK SWANNANOA RIVER NEAR WALKERTOWN, NC       344894205
# 351706800          CHEOAH RIVER NR BEARPEN GAP NR TAPOCO, NC       351706800
# 423205010  IRONDEQUOIT CR ABOVE BLOSSOM RD NEAR ROCHESTER NY       423205010
#
#                                               site_query_url  \
# site_id
# 1011000    https://waterservices.usgs.gov/nwis/site/?form...
# 1013500    https://waterservices.usgs.gov/nwis/site/?form...
# 1015800    https://waterservices.usgs.gov/nwis/site/?form...
# 1017000    https://waterservices.usgs.gov/nwis/site/?form...
# 1017550    https://waterservices.usgs.gov/nwis/site/?form...
# ...                                                      ...
# 214657975  https://waterservices.usgs.gov/nwis/site/?form...
# 242354750  https://waterservices.usgs.gov/nwis/site/?form...
# 344894205  https://waterservices.usgs.gov/nwis/site/?form...
# 351706800  https://waterservices.usgs.gov/nwis/site/?form...
# 423205010  https://waterservices.usgs.gov/nwis/site/?form...
#
#           site_query_access_date   latitude  longitude state      huc  ...  \
# site_id                                                                ...
# 1011000               2022-08-30  47.069722 -69.079444    ME  1010002  ...
# 1013500               2022-08-30  47.237500 -68.582778    ME  1010003  ...
# 1015800               2022-08-30  46.523056 -68.371667    ME  1010004  ...
# 1017000               2022-08-30  46.777222 -68.157222    ME  1010004  ...
# 1017550               2022-08-30  46.628056 -67.953056    ME  1010005  ...
# ...                          ...        ...        ...   ...      ...  ...
# 214657975             2022-08-30  35.158611 -80.713333    NC  3050103  ...
# 242354750             2022-08-30  33.313445 -86.806377    AL  3150202  ...
# 344894205             2022-08-30  35.685278 -82.332778    NC  6010105  ...
# 351706800             2022-08-30  35.438333 -83.918889    NC  6010204  ...
# 423205010             2022-08-30  43.145000 -77.511944    NY  4140101  ...
#
#           basin_cd  topo_cd                  instruments_cd  construction_dt  \
# site_id
# 1011000        NaN      NaN  YNNNYNNNNYNNNNNNYNNNNNNNNNNNNN              NaN
# 1013500        NaN      NaN  YNNNYNYNNYNNNNNNYNNNNNNNNNNNNN              NaN
# 1015800        NaN      NaN  YNNNYNYNNYNNNNNNYNNNNNNNNNNNNN              NaN
# 1017000        NaN      NaN  YNNNYNYNNYNNNNNNYNNNNNNNNNNNNN              NaN
# 1017550        NaN      NaN  YNNNYNYNNYNNNNNNYNNNNNNNNNNNNN              NaN
# ...            ...      ...                             ...              ...
# 214657975     10.0      NaN  YNNYNNNNNNNNNNNNNNNNNNNNNNNNNN              NaN
# 242354750      NaN      NaN  NNNNYNNNNNNNNNNNNNNNNNNNNNNNNN              NaN
# 344894205     12.0      NaN  NNNNYNNNNNNNNNNNNNNNNNNNNNNNNN              NaN
# 351706800     12.0      NaN  NNNNYNNNNNNNNNNNNNNNNNNNNNNNNN              NaN
# 423205010      NaN      NaN  YNYNNNNNNNNNNNNNNNNNNNNNNNNNNN              NaN
#
#           inventory_dt drain_area_va  contrib_drain_area_va  local_time_fg  \
# site_id
# 1011000            NaN       1478.00                1229.00              Y
# 1013500            NaN        873.00                 873.00              Y
# 1015800            NaN        892.00                 892.00              Y
# 1017000            NaN       1654.00                1654.00              Y
# 1017550            NaN          3.82                   3.82              Y
# ...                ...           ...                    ...            ...
# 214657975          NaN          8.37                    NaN              Y
# 242354750          NaN         25.60                  25.60              Y
# 344894205   19890130.0         14.50                    NaN              Y
# 351706800          NaN        206.00                    NaN              Y
# 423205010          NaN        142.00                 134.22              N
#
#           reliability_cd   project_no
# site_id
# 1011000              NaN  442300100.0
# 1013500              NaN  442300100.0
# 1015800              NaN  442300100.0
# 1017000              NaN  442300100.0
# 1017550              NaN  442300100.0
# ...                  ...          ...
# 214657975            NaN    453700100
# 242354750            NaN          NaN
# 344894205            NaN    453700100
# 351706800            NaN    453700100
# 423205010            NaN          NaN
#
# [4418 rows x 82 columns]

# %% [markdown]
# ### Calculate statistics

# %%
np.sum(pf_flow_matched.iloc[1])
#pf_flow_matched.iloc[1]
# Out:
# 194.51368931395152

# %%
# set up DF for daily stats
stats_df = pd.DataFrame(columns = ['USGS_lat', 'USGS_lon', 'x_new_adj', 
                         'y_new_adj', 'r2', 'srho', 'mse', 'rmse', 'nse', 'bias', 'pbias', 'absbias', 'relbias']) #scaled RMSE

stats_df['USGS_lat'] = pfdata['USGS_lat']
stats_df['USGS_lon'] = pfdata['USGS_lon']
stats_df['x_new_adj'] = pfdata['x_new_adj']
stats_df['y_new_adj'] = pfdata['y_new_adj']
print(stats_df.shape)
stats_df.head()
# Out:
# (4418, 13)
#           USGS_lat   USGS_lon  x_new_adj  y_new_adj   r2 srho  mse rmse  nse  \
# site_id
# 1011000  47.069611 -69.079544       4210       2783  NaN  NaN  NaN  NaN  NaN
# 1013500  47.237394 -68.582642       4237       2810  NaN  NaN  NaN  NaN  NaN
# 1015800  46.523003 -68.371764       4276       2747  NaN  NaN  NaN  NaN  NaN
# 1017000  46.777294 -68.157194       4281       2773  NaN  NaN  NaN  NaN  NaN
# 1017550  46.628056 -67.953056       4300       2762  NaN  NaN  NaN  NaN  NaN
#
#         bias pbias absbias relbias
# site_id
# 1011000  NaN   NaN     NaN     NaN
# 1013500  NaN   NaN     NaN     NaN
# 1015800  NaN   NaN     NaN     NaN
# 1017000  NaN   NaN     NaN     NaN
# 1017550  NaN   NaN     NaN     NaN

# %%
# Set up array for stats
r2_daily = np.zeros(len(usgs_flow_matched.index))
srho_daily = np.zeros(len(usgs_flow_matched.index))
pval_daily = np.zeros(len(usgs_flow_matched.index))
mse_daily = np.zeros(len(usgs_flow_matched.index))
rmse_daily = np.zeros(len(usgs_flow_matched.index))
nse_daily = np.zeros(len(usgs_flow_matched.index))
pbias_daily = np.zeros(len(usgs_flow_matched.index))
absbias_daily = np.zeros(len(usgs_flow_matched.index))
relbias_daily = np.zeros(len(usgs_flow_matched.index))
r2_daily.shape
# Out:
# (4418,)

# %%
test_pbias = he.pbias(np.array(pf_flow_matched.iloc[1]), np.array(usgs_flow_matched.iloc[1]))
test_pbias
np.where(pf_flow_matched == 0)
test_srho = stats.spearmanr(usgs_flow_matched.iloc[1], pf_flow_matched.iloc[1])
test_srho.correlation
# Out:
# 0.9648079497627615

# %%
for g in range(len(usgs_flow_matched.index)):
    gage = usgs_flow_matched.index[g]
    absbias_daily[g] = (abs(np.sum(pf_flow_matched.loc[gage])-np.sum(usgs_flow_matched.loc[gage])))/np.sum(usgs_flow_matched.loc[gage]) #absolute percent bias
    mse_daily[g] = mean_squared_error(usgs_flow_matched.loc[gage], pf_flow_matched.loc[gage])
    rmse_daily[g] = sqrt(mean_squared_error(usgs_flow_matched.loc[gage], pf_flow_matched.loc[gage]))
    r2_daily[g] = r2_score(usgs_flow_matched.loc[gage], pf_flow_matched.loc[gage])
    #srho_daily[g], pval_daily[g] = stats.spearmanr(usgs_flow_matched.loc[gage], pf_flow_matched.loc[gage])
    #nse_daily[g] = he.nse(np.sum(pf_flow_matched.loc[gage]), np.sum(usgs_flow_matched.loc[gage]))
    #print(pf_flow_matched.loc[gage])
    # print(usgs_flow_matched.loc[gage])
    
    #import necessary libraries


#calculate RMSE
# sqrt(mean_squared_error(actual, pred))

# %%
for g in range(len(usgs_flow_matched.index)):
    gage = usgs_flow_matched.index[g]
    absbias_daily[g] = (abs(np.sum(pf_flow_matched.loc[gage])-np.sum(usgs_flow_matched.loc[gage])))/np.sum(usgs_flow_matched.loc[gage]) #absolute percent bias
    mse_daily[g] = mean_squared_error(usgs_flow_matched.loc[gage], pf_flow_matched.loc[gage])
    rmse_daily[g] = sqrt(mean_squared_error(usgs_flow_matched.loc[gage], pf_flow_matched.loc[gage]))
    r2_daily[g] = r2_score(usgs_flow_matched.loc[gage], pf_flow_matched.loc[gage])
    srho_daily[g], pval_daily[g] = stats.spearmanr(usgs_flow_matched.loc[gage], pf_flow_matched.loc[gage])
    #nse_daily[g] = he.nse(np.sum(pf_flow_matched.loc[gage]), np.sum(usgs_flow_matched.loc[gage]))
    #print(pf_flow_matched.loc[gage])
    # print(usgs_flow_matched.loc[gage])
    
    #import necessary libraries


#calculate RMSE
# sqrt(mean_squared_error(actual, pred))

# %%
stats_df['absbias'] = absbias_daily
stats_df['mse'] = mse_daily
stats_df['rmse'] = rmse_daily
stats_df['r2'] = r2_daily
stats_df['srho'] = srho_daily

# %%
stats_df.head()
# Out:
#           USGS_lat   USGS_lon  x_new_adj  y_new_adj        r2  srho  \
# site_id
# 1011000  47.069611 -69.079544       4210       2783 -0.331434   0.0
# 1013500  47.237394 -68.582642       4237       2810 -4.246291   0.0
# 1015800  46.523003 -68.371764       4276       2747 -0.843453   0.0
# 1017000  46.777294 -68.157194       4281       2773 -1.814542   0.0
# 1017550  46.628056 -67.953056       4300       2762 -6.795238   0.0
#
#                 mse       rmse  nse bias pbias   absbias relbias
# site_id
# 1011000   17.735233   4.211322  NaN  NaN   NaN  0.118918     NaN
# 1013500   16.026274   4.003283  NaN  NaN   NaN  0.460783     NaN
# 1015800   63.624485   7.976496  NaN  NaN   NaN  0.171624     NaN
# 1017000  286.623200  16.929950  NaN  NaN   NaN  0.270155     NaN
# 1017550    0.003824   0.061836  NaN  NaN   NaN  0.537057     NaN

# %%
x_length = range(len(stats_df.index))
x_length
# Out:
# range(0, 4418)

# %%
plt.scatter(x_length, srho_daily)
plt.show()

# %%
plt.scatter(x_length, rmse_daily)

# %%
plt.scatter(pf_flow_matched.loc[1011000], usgs_flow_matched.loc[1011000])
plt.xlabel('pf flow')
plt.ylabel('usgs flow')
# Out:
# Text(0, 0.5, 'usgs flow')

# %%
fig = plt.figure(figsize=(19,10), dpi=72)
plt.scatter(stats_df.USGS_lon,stats_df.USGS_lat, c=stats_df.mse, s=20)
plt.colorbar()
plt.show()

# %%
ax.scatter(usgs_daily_flow['daily mean'], CONUS2_daily_flow['daily mean'], color = 'dimgrey')
ax.plot(range(1000), color = 'lightcoral')
plt.ylabel('PFCLM flow (cms)',fontsize=18)
plt.xlabel('USGS flow (cms)',fontsize=18)
plt.title('Daily mean flow comparison, October WY2003 (cms)',fontsize=20)
ax.xaxis.set_tick_params(labelsize=16)
ax.yaxis.set_tick_params(labelsize=16)
# square plot
ax.set_aspect('equal', adjustable='box')
#plt.savefig(f'{plot_dir}/Oct_WY2003_daily_mean_flow_comparison_scatter.png')
