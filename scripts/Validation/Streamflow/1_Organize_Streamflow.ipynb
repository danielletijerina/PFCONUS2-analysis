# %%
### Make CSV of CONUS2 flow at matched gages ###
### DTT, 10/22

# This script is split into two main parts: 1) reading in CONUS2 gridded total (aggregated) daily flow for the full domain and creating a dataframe of CONUS2 flow for cells that have been matched with USGS gages in the `NWM_Gage_Adjustments_final.csv`. 2) matching the gages that both have flow between the PF csv and USGS csv retrieved from hydrodata. 
# Note that flow is converted in this script from daily accumulated flow in [m^3/h] to daily mean flow in cms or [m^3/s].

### Inputs:
# - `NWM_Gage_Adjustments_final.csv` - this can be found on the CONUS2 Dropbox or in /glade/p/univ/ucsm0002/CONUS2/domain_files
# - Daily total streamflow PFCLM outputs as PFBs - processed using `compute_daily_PF_averages.py`
# - USGS daily flow csv - from the hydrodata repository on Verde

### Outputs:
# - CSV of PFCLM daily mean flow (cms) with gage ID, lat/long, and CONUS2 cell location
# - two flow-matched CSVs for PF and USGS flow
# - note that the CSV outputs with 'day 001' which starts at the water year (001 == October 1)***

# Notes:
# - need to fix the no_days, currently this will only be accurate if this is started at the begninning of a water year and need to add in some dictionary or if statement to specify num days in a month or something like that.
# - ***need to change day headings so that they are more descriptive than 'day 001' and have an actual date

import sys
from parflow.tools.io import read_pfb,write_pfb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Directory where PF flow PFBs are saved in
directory_out = '/glade/p/univ/ucsm0002/CONUS2/CONUS2.spinup.WY2003/averages'
organized_dir = '/glade/work/tijerina/PFCONUS2-analysis/scripts/Validation/Streamflow/Organized_Daily_Flow'

usgs_data = 'USGS_WY2003_oct_mean_flow_HydroData.csv' #csv of USGS flow from hydrodata

# need to change water year and number of days
water_year = 2003
no_days = 364 

### check gage locations for daily flow
NWM_gage_csv = pd.read_csv('/glade/p/univ/ucsm0002/CONUS2/domain_files/NWM_Gage_Adjustments_final.csv')


### set up pandas dataframe of gage ID, lat/long, CONUS2 x and y indices ###
pf_flow_df = pd.DataFrame(columns = ['STNID', 'USGS_lat', 'USGS_lon', 'x_new_adj', 'y_new_adj'])
pf_flow_df['STNID'] = NWM_gage_csv['STNID'].astype(int)
pf_flow_df['USGS_lat'] = NWM_gage_csv['USGS_lat']
pf_flow_df['USGS_lon'] = NWM_gage_csv['USGS_lon']
pf_flow_df['x_new_adj'] = NWM_gage_csv['x_new_adj']
pf_flow_df['y_new_adj'] = NWM_gage_csv['y_new_adj']

# add leading zeros to USGS gages
pf_flow_df['STNID'] = pf_flow_df['STNID'].astype('str').str.zfill(8)

pf_flow_df
# Out:
#          STNID   USGS_lat    USGS_lon  x_new_adj  y_new_adj
# 0     01011000  47.069611  -69.079544       4210       2783
# 1     01013500  47.237394  -68.582642       4237       2810
# 2     01015800  46.523003  -68.371764       4276       2747
# 3     01017000  46.777294  -68.157194       4281       2773
# 4     01017060  46.783611  -67.989167       4295       2780
# ...        ...        ...         ...        ...        ...
# 7537  11455350  38.212778 -121.669167        142       1797
# 7538  11447905  38.238804 -121.522731        151       1792
# 7539  11447903  38.237222 -121.517500        149       1790
# 7540  11455420  38.149044 -121.688944        139       1789
# 7541  11337190  38.052142 -121.688843        134       1779
#
# [7542 rows x 5 columns]

# %%
### READ STREAMFLOW PFBs ###
# Read in CONUS2 daily streamflow PFBs and save as df in flow_df, convert to total accumulated in m^3/h to mean daily in cms
for i in range(no_days):
    step = str(int(i+1)).rjust(3, '0')
    pf_flow_pfb = np.squeeze(read_pfb(f'{directory_out}/flow.2003.daily.{step}.pfb'))
    pf_flow_df[f'day {step}'] = pf_flow_pfb[pf_flow_df['y_new_adj'],pf_flow_df['x_new_adj']]/3600/24 # CONVERT FROM m^3/h to cms AND from daily accumulated to daily mean
    print(f'reading flow for day {step} and converting from total accumulated flow in m^3/h, to daily mean flow in cms')

    
# Create column for matching/have flow (=1) and not matching/have no flow (=0) gages
pf_flow_df['matched'] = np.where(pf_flow_df['day 001']>0, 1, 0)

# remove cells with no flow and make new pandas df with matching flow at CONUS2 cells and USGS gages
pf_flow_df_NWM_match = pf_flow_df[pf_flow_df.matched != 0]

# SAVE OUT PANDAS DF FOR CONUS2 FLOW
### save csv file of all matching gage locations and CONUS2 daily flow, note the USGS STNID's drop the leading zeros when saving
pf_flow_df_NWM_match.to_csv(f'{organized_dir}/CONUS2_NWM_matched_flow_{water_year}.csv', sep = ",")
# Out:
# reading flow for day 001 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 002 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 003 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 004 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 005 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 006 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 007 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 008 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 009 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 010 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 011 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 012 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 013 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 014 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 015 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 016 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 017 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 018 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 019 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 020 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 021 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 022 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 023 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 024 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 025 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 026 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 027 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 028 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 029 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 030 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 031 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 032 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 033 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 034 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 035 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 036 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 037 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 038 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 039 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 040 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 041 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 042 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 043 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 044 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 045 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 046 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 047 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 048 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 049 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 050 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 051 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 052 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 053 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 054 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 055 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 056 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 057 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 058 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 059 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 060 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 061 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 062 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 063 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 064 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 065 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 066 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 067 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 068 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 069 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 070 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 071 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 072 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 073 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 074 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 075 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 076 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 077 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 078 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 079 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 080 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 081 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 082 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 083 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 084 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 085 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 086 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 087 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 088 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 089 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 090 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 091 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 092 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 093 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 094 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 095 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# /glade/work/tijerina/conda-envs/parflow-npl/lib/python3.7/site-packages/ipykernel_launcher.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# reading flow for day 096 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 097 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 098 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 099 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 100 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 101 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 102 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 103 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 104 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 105 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 106 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 107 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 108 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 109 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 110 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 111 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 112 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 113 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 114 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 115 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 116 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 117 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 118 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 119 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 120 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 121 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 122 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 123 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 124 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 125 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 126 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 127 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 128 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 129 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 130 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 131 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 132 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 133 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 134 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 135 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 136 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 137 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 138 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 139 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 140 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 141 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 142 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 143 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 144 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 145 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 146 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 147 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 148 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 149 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 150 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 151 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 152 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 153 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 154 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 155 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 156 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 157 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 158 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 159 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 160 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 161 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 162 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 163 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 164 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 165 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 166 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 167 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 168 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 169 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 170 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 171 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 172 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 173 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 174 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 175 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 176 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 177 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 178 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 179 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 180 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 181 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 182 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 183 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 184 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 185 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 186 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 187 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 188 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 189 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 190 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 191 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 192 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 193 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 194 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 195 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 196 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 197 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 198 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 199 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 200 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 201 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 202 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 203 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 204 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 205 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 206 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 207 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 208 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 209 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 210 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 211 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 212 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 213 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 214 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 215 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 216 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 217 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 218 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 219 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 220 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 221 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 222 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 223 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 224 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 225 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 226 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 227 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 228 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 229 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 230 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 231 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 232 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 233 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 234 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 235 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 236 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 237 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 238 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 239 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 240 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 241 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 242 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 243 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 244 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 245 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 246 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 247 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 248 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 249 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 250 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 251 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 252 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 253 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 254 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 255 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 256 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 257 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 258 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 259 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 260 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 261 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 262 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 263 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 264 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 265 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 266 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 267 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 268 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 269 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 270 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 271 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 272 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 273 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 274 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 275 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 276 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 277 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 278 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 279 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 280 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 281 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 282 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 283 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 284 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 285 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 286 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 287 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 288 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 289 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 290 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 291 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 292 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 293 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 294 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 295 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 296 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 297 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 298 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 299 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 300 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 301 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 302 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 303 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 304 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 305 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 306 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 307 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 308 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 309 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 310 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 311 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 312 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 313 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 314 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 315 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 316 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 317 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 318 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 319 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 320 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 321 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 322 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 323 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 324 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 325 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 326 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 327 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 328 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 329 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 330 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 331 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 332 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 333 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 334 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 335 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 336 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 337 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 338 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 339 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 340 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 341 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 342 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 343 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 344 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 345 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 346 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 347 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 348 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 349 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 350 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 351 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 352 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 353 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 354 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 355 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 356 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 357 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 358 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 359 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 360 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 361 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 362 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 363 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# reading flow for day 364 and converting from total accumulated flow in m^3/h, to daily mean flow in cms
# /glade/work/tijerina/conda-envs/parflow-npl/lib/python3.7/site-packages/ipykernel_launcher.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   # This is added back by InteractiveShellApp.init_path()

# %% [raw]
# pf_flow_df_NWM_match

# %%
###
### read in csv that was just created of gage locations and CONUS2 flow
pf_flow_df = pd.read_csv(f'{organized_dir}/CONUS2_NWM_matched_flow_{water_year}.csv',index_col=['STNID'])
pf_flow_df = pf_flow_df.drop(columns=['Unnamed: 0','matched']) #drop unnecessary columns for now
pf_flow_df.index.names = ['site_id']
                          
### read in USGS flow for all gages with flow in October
# streamflow from hydrodata has already been converted to cms!!!
usgs_flow_df = pd.read_csv(f'{organized_dir}/{usgs_data}',index_col=['site_id']) 
usgs_flow_df = usgs_flow_df.drop(columns=['Unnamed: 0', 'num_obs'])
                          
# # merge the CONUS2 and USGS dataframes so that we remove all gage locations that don't match between the two
# combine_df = pf_flow_df.merge(usgs_flow_df, on='site_id', how='inner')
# combine_df

# find matching gage locations (index = 'site_id') between the PF flow and USGS flow 
# result is a list of matching indices ('match_index') which is then used to parse down the PF and USGS flow dataframes 
pf_flow_index = pf_flow_df.index
usgs_flow_index = usgs_flow_df.index
match_index = pf_flow_index.intersection(usgs_flow_index)
print(f'There are {len(match_index)} matching gages between PF and USGS!')
# Out:
# There are 4999 matching gages between PF and USGS!

# %%
# reorganize PF flow dataframe to keep only gages that match with USGS
pf_flow_matched = pf_flow_df[pf_flow_df.index.isin(match_index)]
print(pf_flow_matched.shape)
pf_flow_matched.head()
# Out:
# (4999, 35)
#           USGS_lat   USGS_lon  x_new_adj  y_new_adj    day 001    day 002  \
# site_id
# 1011000  47.069611 -69.079544       4210       2783  37.266464  34.151593
# 1013500  47.237394 -68.582642       4237       2810  18.686342  17.994405
# 1015800  46.523003 -68.371764       4276       2747  30.468728  29.614383
# 1017000  46.777294 -68.157194       4281       2773  64.752051  64.284799
# 1017550  46.628056 -67.953056       4300       2762   0.044492   0.028687
#
#            day 003    day 004    day 005    day 006  ...    day 022  \
# site_id                                              ...
# 1011000  31.949418  28.746042  24.794453  21.037749  ...  26.366490
# 1013500  17.171830  14.470901  14.358695  12.452931  ...  25.460269
# 1015800  27.459663  24.822553  22.551353  19.456863  ...  58.912677
# 1017000  62.117018  57.702024  52.771326  48.076338  ...  67.899391
# 1017550   0.010159   0.003003   0.004380   0.001411  ...   0.155844
#
#            day 023     day 024     day 025     day 026    day 027    day 028  \
# site_id
# 1011000  42.798333   53.046882   43.618294   34.649396  32.664747  28.395134
# 1013500  25.297993   25.892275   26.625347   25.821571  29.422915  27.471481
# 1015800  71.743174   63.942664   52.078266   42.038084  36.339844  30.665801
# 1017000  94.396899  100.104568  110.776426  108.378785  96.324758  83.791588
# 1017550   0.092079    0.059114    0.039842    0.053557   0.127573   0.071467
#
#            day 029    day 030    day 031
# site_id
# 1011000  27.141300  25.504890  25.276254
# 1013500  23.582704  20.091685  17.376020
# 1015800  28.090918  26.373447  24.965231
# 1017000  75.230466  67.490577  59.051520
# 1017550   0.049377   0.033976   0.025259
#
# [5 rows x 35 columns]

# %%
# reorganize USGS flow dataframe to keep only gages that match with PF
usgs_flow_matched = usgs_flow_df[usgs_flow_df.index.isin(match_index)]
# reindex so that USGS is in the same order as the PF dataframe
usgs_flow_matched = usgs_flow_matched.reindex(index=pf_flow_matched.index)
print(usgs_flow_matched.shape)
usgs_flow_matched
# Out:
# (4999, 31)
#            2002-10-01  2002-10-02  2002-10-03  2002-10-04  2002-10-05  \
# site_id
# 1011000      7.414600    7.386300    6.990100    6.565600    6.367500
# 1013500      3.509200    3.424300    3.169600    3.113000    3.339400
# 1015800      6.707100    6.226000    5.716600    5.377000    5.150600
# 1017000      9.876700    9.367300    8.461700    7.952300    7.810800
# 1017550      0.023772    0.024338    0.020659    0.018395    0.019810
# ...               ...         ...         ...         ...         ...
# 242354750    0.882960    0.755610    0.642410    0.588640    0.537700
# 344894205    0.718820    0.585810    0.486760    0.424500    0.396200
# 351706800    1.015970    0.885790    0.809380    0.741460    0.979180
# 422026250    0.166404    0.167819    0.190742    0.171781    0.175743
# 423205010    1.171620    1.052760    1.525370    1.265010    1.098040
#
#            2002-10-06  2002-10-07  2002-10-08  2002-10-09  2002-10-10  ...  \
# site_id                                                                ...
# 1011000      6.197700    5.744900    5.065700    4.528000    4.414800  ...
# 1013500      2.858300    2.858300    2.631900    2.405500    2.504550  ...
# 1015800      5.037400    4.754400    4.499700    4.160100    4.188400  ...
# 1017000      7.131600    7.046700    6.678800    6.282600    6.282600  ...
# 1017550      0.019810    0.018678    0.018678    0.018961    0.021791  ...
# ...               ...         ...         ...         ...         ...  ...
# 242354750    0.520720    6.480700    2.363050    1.417830    1.092380  ...
# 344894205    0.348090    0.305640    0.283000    0.272246    0.273944  ...
# 351706800    0.829190    1.013140    0.942390    0.772590    0.730140  ...
# 422026250    0.169517    0.170366    0.166121    0.167253    0.166404  ...
# 423205010    1.015970    0.945220    0.911260    0.919750    1.086720  ...
#
#            2002-10-22  2002-10-23  2002-10-24  2002-10-25  2002-10-26  \
# site_id
# 1011000      9.310700    8.574900    8.546600    8.631500    9.820100
# 1013500      5.263800    5.405300    5.660000    5.914700    6.197700
# 1015800     22.300400   19.074200   16.725300   14.914100   13.725500
# 1017000     38.205000   33.394000   28.583000   24.507800   21.762700
# 1017550      0.044997    0.036790    0.036224    0.035092    0.030847
# ...               ...         ...         ...         ...         ...
# 242354750    0.667880    0.608450    0.577320    0.554680    0.554680
# 344894205    0.452800    0.407520    0.373560    0.370730    0.399030
# 351706800    0.843340    0.769760    0.732970    0.741460    0.837680
# 422026250    0.191874    0.253568    0.198666    0.190742    0.251870
# 423205010    1.010310    1.700830    1.548010    1.284820    2.561150
#
#            2002-10-27  2002-10-28  2002-10-29  2002-10-30  2002-10-31
# site_id
# 1011000     12.508600   15.508400   16.527200   15.791400   14.319800
# 1013500      6.990100    7.556100    7.301400    7.188200    7.273100
# 1015800     12.904800   12.848200   13.725500   13.725500   13.074600
# 1017000     20.376000   20.715600   21.791000   21.734400   20.347700
# 1017550      0.041884    0.051789    0.039620    0.031979    0.027451
# ...               ...         ...         ...         ...         ...
# 242354750    0.543360    1.313120    1.652720    1.426320    1.075400
# 344894205    0.370730    0.582980    0.795230    1.058420    0.911260
# 351706800    0.766930    1.267840    1.859310    4.273300    2.447950
# 422026250    0.210552    0.199515    0.198383    0.197251    0.190459
# 423205010    1.833840    1.437640    2.221550    2.289470    1.649890
#
# [4999 rows x 31 columns]

# %% [markdown]
# ### Reorganize metadata for flow matched gages

# %%
### read in USGS streamflow gage metadata for all gages with flow in October
usgs_gage_metadata = pd.read_csv(f'{organized_dir}/USGS_WY2003_oct_raw_metadata.csv',index_col=['site_id'])#, 
usgs_gage_metadata = usgs_gage_metadata.drop(columns=['Unnamed: 0'])
#usgs_all_gages = usgs_all_gages.transpose() #transpose df for easier plotting
usgs_gage_metadata.shape
# Out:
# (5874, 82)

# %%
# reorganize USGS metadata dataframe to keep only gages that match with PF and USGS
meta_flow_matched = usgs_gage_metadata[usgs_gage_metadata.index.isin(match_index)]
# reindex so that metadata is in the same order as the PF dataframe
meta_flow_matched = meta_flow_matched.reindex(index=pf_flow_matched.index)
meta_flow_matched.shape
# Out:
# (4999, 82)

# %%
# Do a check to make sure that all dataframes have the same indexes
if pf_flow_matched.index.equals(usgs_flow_matched.index) == True: 
    print('PF and USGS gages MATCH!!! Now, save the dataframes for use in other scripts.')
else:
    print('Gages DO NOT match between PF and USGS! Go back and check the dataframes...')
    
    
# check metadata also has the same gages as these
if meta_flow_matched.index.equals(usgs_flow_matched.index):
    print('Metadata and USGS gages MATCH!!! Now, save the dataframes for use in other scripts.')
else:
    print('Gages DO NOT match between metadata dataframe and USGS! Go back and check the metadata workflow...')
# Out:
# PF and USGS gages MATCH!!! Now, save the dataframes for use in other scripts.
# Metadata and USGS gages MATCH!!! Now, save the dataframes for use in other scripts.

# %%
# Save Flow Matched CSVs
pf_flow_matched.to_csv(f'{organized_dir}/FlowMatch_CONUS2_daily_cms_{water_year}.csv', sep = ",")
usgs_flow_matched.to_csv(f'{organized_dir}/FlowMatch_USGS_daily_cms_{water_year}.csv', sep = ",")#usgs_flow_matched
meta_flow_matched.to_csv(f'{organized_dir}/FlowMatch_metadata_{water_year}.csv', sep = ",")
