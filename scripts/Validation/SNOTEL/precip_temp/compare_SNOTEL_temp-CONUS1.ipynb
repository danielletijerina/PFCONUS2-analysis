# %% [markdown]
# # Compare SNOTEL temperature observations to CW3E forcing
# D. Tijerina, 5/2023
#
# This script reads in SNOTEL observations queried from Hydrodata and compares to CW3E forcing. The notebook is broken up into these sections:
# 1. Read in SNOTEL observations and metadata; organize into pandas dataframes
# 2. Read in CW3E forcing over CONUS2 and extract indices for CONUS2 grid cells that are common to the SNOTEL observations; organize all data
# 3. Compute statistics between CW3E and SNOTEL observations
# 4. Create summary plots, maps, and individual station timeseries
#
#
# Inputs:
# - SNOTEL Metadata csv file of stations from a Hydrodata query (from point_observations.ipynb)
# - SNOTEL Observation data csv file of stations from a Hydrodata query (from point_observations.ipynb)
#
# Outputs:
# - Matched CW3E/ParFlow temperature csv
# - Rematched Metadata file csv
# - Rematched SNOTEL observation file csv
# - Summary station SNOTEL csv containing station info, CONUS x and y, averages, statistics
# - Timeseries of SNOTEL variable vs. ParFlow at individual stations
# - Summary plots/maps
#
# Notes:
# - Need to add a basemap to summary plots (Geopandas? Basemap from matplot.toolkit?)

# %%
import sys
from parflow.tools.io import read_pfb,write_pfb
import numpy as np
import pandas as pd

# %%
### Directory to save CSV outputs
organized_dir = './Organized_csv/temperature'

### Where you want to save plots, etc. to
#plot_dir = '/glade/work/tijerina/PFCONUS2-analysis/scripts/Validation/Streamflow/Figures'
#plot_dir = '/home/dtt2/CONUS2/PFCONUS2-analysis/scripts/Validation/SNOTEL/precip_temp/Figures'
plot_dir = './Figures/'
print(f'Figures saving to: {plot_dir}')

# need to change water year and number of days
water_year = 2003
no_days = 365 
variable = 'Temp_C' 

# CONUS2 domain
ny = 1888 
nx = 3342
# Out:
# Figures saving to: ./Figures/

# %%
from PIL import Image

# Read in CONUS2 mask for map plot border
CONUS2_mask = Image.open('/hydrodata/PFCLM/CONUS2_baseline/inputs/domain_files/CONUS2.0.Final1km.Mask.tif')
#CONUS2_mask = Image.open('/home/dtt2/CONUS2/shape_files/CONUS2_HUC2_boundaries_clipped.tif')
mask_array = np.array(CONUS2_mask)

# %% [markdown]
# ##### Names of observation csv files, these are usually saved from Hydrodata

# %%
# Files for SNOTEL average temperature observations (in C) from Hydrodata
data_file = 'Hydrodata_temperature_obs_daily_average_WY2003.csv'
metadata_file = 'Hydrodata_temperature_metadata_daily_average_WY2003.csv'

# %% [markdown]
# ##### Name of path and file name of PFB reading in
# CW3E (CONUS2 Forcing)

# %%
# path to daily forcing PFB files
pfb_read_path = f'/hydrodata/forcing/processed_data/CONUS1/NLDAS2/daily/WY{water_year}'
print(pfb_read_path)
# This is the partial name of the pfb, without the timestamp or .pfb file extension
# (for example, 'NLDAS.APCP.daily.sum.008.pfb' -> 'NLDAS.APCP.daily.sum')
pfb_name = 'NLDAS.Temp.daily.mean'
# Out:
# /hydrodata/forcing/processed_data/CONUS1/NLDAS2/daily/WY2003

# %% [markdown]
# ##### Create file names for all files you will save out
# These include:
# - CSV of ParFlow or CW3E modeled values from pfb at station-matched CONUS2 x, y
# - Rematched observation csv file (this is a reorganized version of `data_file`
# - Rematched observation metadata csv file (this is a reorganized version of `metadata_file`
# - Summary statistics csv with station info and stats for each station

# %%
### Name files you will save out
# names of csv files for model and observations that contain the same stations
pf_matched_csv = f'NLDAS2_Daily_matched_CONUS1_{variable}_{water_year}.csv'
snotel_matched_csv = f'SNOTEL_Daily_matched_CONUS1_{variable}_{water_year}.csv'
metadata_matched_csv = f'SNOTEL_metadata_matched_CONUS1_{variable}_{water_year}.csv'
# summary stats
summary_stats_csv = f'Summary_Stations_CONUS1_SNOTEL_{variable}_WY{water_year}.csv'

# %% [markdown]
# # 1. Read in SNOTEL observations and organize

# %% [markdown]
# ### SNOTEL Avg Daily Temperature

# %%
obs_data = pd.read_csv(f'{organized_dir}/{data_file}', index_col=['site_id'])
obs_data  = obs_data.drop(columns=['Unnamed: 0'])
#stats_df = stats_df.where(stats_df['SNOTEL_mean_T_C']<45, 'nan')
obs_data = obs_data.loc[(obs_data['num_obs']>=365)] # I arbitrarily set this to only include sites with more than 340 days of observations
obs_data
# Out:
#               2002-10-01  2002-10-02  2002-10-03  2002-10-04  2002-10-05  \
# site_id
# 1005:CO:SNTL         5.2         3.4         0.6         1.8         5.0
# 1008:MT:SNTL        -2.9        -1.0        -0.3         0.6        -0.1
# 1009:MT:SNTL        -1.2        -0.4         0.6         2.0         1.3
# 1014:CO:SNTL         5.3         4.9         1.1         1.9         3.0
# 1015:WY:SNTL         6.6         4.2         1.9         2.8         4.8
# ...                  ...         ...         ...         ...         ...
# 981:MT:SNTL         -0.2         0.6         3.1         4.4         5.9
# 982:WY:SNTL          1.9         0.0         4.0         2.5         3.4
# 985:WA:SNTL          5.6         7.8         7.9         8.7        10.3
# 989:ID:SNTL          3.9         5.8         5.1         6.8         6.8
# 990:WA:SNTL          3.3         4.5         6.6         7.3         7.5
#
#               2002-10-06  2002-10-07  2002-10-08  2002-10-09  2002-10-10  ...  \
# site_id                                                                   ...
# 1005:CO:SNTL         3.5         3.8         3.5         4.9         4.5  ...
# 1008:MT:SNTL         2.5         5.3         2.7         4.8         5.4  ...
# 1009:MT:SNTL         3.1         5.4         3.1         3.7         5.3  ...
# 1014:CO:SNTL         3.1         4.5         4.1         3.7         4.9  ...
# 1015:WY:SNTL         6.6         8.3         7.3         8.0         9.9  ...
# ...                  ...         ...         ...         ...         ...  ...
# 981:MT:SNTL          8.2        12.0         7.0        11.2        13.6  ...
# 982:WY:SNTL          2.9         8.5         4.1         8.3        12.0  ...
# 985:WA:SNTL         13.0        13.6        12.4        12.0         6.8  ...
# 989:ID:SNTL          9.3        10.7        10.1         9.2         4.1  ...
# 990:WA:SNTL          8.1         7.5         7.3         6.9         2.9  ...
#
#               2003-09-22  2003-09-23  2003-09-24  2003-09-25  2003-09-26  \
# site_id
# 1005:CO:SNTL         7.1         9.4         7.5         7.6         9.0
# 1008:MT:SNTL         8.2         7.8         5.7        11.4         7.9
# 1009:MT:SNTL         8.0         8.9         6.3        11.9         8.0
# 1014:CO:SNTL         6.2         7.4         7.0         7.1         7.9
# 1015:WY:SNTL        11.1        13.5        12.3        13.5        12.9
# ...                  ...         ...         ...         ...         ...
# 981:MT:SNTL         13.5        14.0         8.7        19.8        12.1
# 982:WY:SNTL          9.4        13.1         4.9        12.6         6.6
# 985:WA:SNTL         16.7        16.6        17.3        19.8        19.7
# 989:ID:SNTL         13.3        13.4        14.8        15.6        16.7
# 990:WA:SNTL         10.9        10.5        10.7        13.1        12.1
#
#               2003-09-27  2003-09-28  2003-09-29  2003-09-30  num_obs
# site_id
# 1005:CO:SNTL         8.7         6.7         8.0         7.6      365
# 1008:MT:SNTL         5.9         5.5         2.4         4.2      365
# 1009:MT:SNTL         6.0         6.0         3.3         3.9      365
# 1014:CO:SNTL         7.0         7.5         8.3         8.3      365
# 1015:WY:SNTL        10.4         8.5         8.3         6.7      365
# ...                  ...         ...         ...         ...      ...
# 981:MT:SNTL         10.2         9.3         5.3         7.5      365
# 982:WY:SNTL          6.7         5.5         2.7         4.1      365
# 985:WA:SNTL         19.4        19.7        17.2        16.7      365
# 989:ID:SNTL         17.3        17.7        15.4        18.2      365
# 990:WA:SNTL         13.5        13.5        12.8        11.9      365
#
# [291 rows x 366 columns]

# %%
metadata = pd.read_csv(f'{organized_dir}/{metadata_file}', index_col=['site_id'])
metadata  = metadata.drop(columns=['Unnamed: 0'])
# also remove the sites with less than 340 obs from the metadata
metadata = metadata[metadata.index.isin(obs_data.index)]
# add number of observations column from the obs_data df
metadata['num_obs'] = obs_data['num_obs']
obs_data = obs_data.drop(columns=['num_obs'])
metadata
# Out:
#                    site_type agency         site_name site_id_agency  \
# site_id
# 1005:CO:SNTL  SNOTEL station   NRCS         Ute Creek   1005:CO:SNTL
# 1008:MT:SNTL  SNOTEL station   NRCS        Onion Park   1008:MT:SNTL
# 1009:MT:SNTL  SNOTEL station   NRCS    Stringer Creek   1009:MT:SNTL
# 1014:CO:SNTL  SNOTEL station   NRCS  Middle Fork Camp   1014:CO:SNTL
# 1015:WY:SNTL  SNOTEL station   NRCS  Sage Creek Basin   1015:WY:SNTL
# ...                      ...    ...               ...            ...
# 981:MT:SNTL   SNOTEL station   NRCS         Burnt Mtn    981:MT:SNTL
# 982:WY:SNTL   SNOTEL station   NRCS       Cole Canyon    982:WY:SNTL
# 985:WA:SNTL   SNOTEL station   NRCS   Sourdough Gulch    985:WA:SNTL
# 989:ID:SNTL   SNOTEL station   NRCS   Moscow Mountain    989:ID:SNTL
# 990:WA:SNTL   SNOTEL station   NRCS       Beaver Pass    990:WA:SNTL
#
#                                                  site_query_url  \
# site_id
# 1005:CO:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 1008:MT:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 1009:MT:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 1014:CO:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 1015:WY:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# ...                                                         ...
# 981:MT:SNTL   https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 982:WY:SNTL   https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 985:WA:SNTL   https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 989:ID:SNTL   https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 990:WA:SNTL   https://wcc.sc.egov.usda.gov/awdbWebService/we...
#
#              date_metadata_last_updated  latitude  longitude state  \
# site_id
# 1005:CO:SNTL                 2023-03-07  37.61480 -105.37322    CO
# 1008:MT:SNTL                 2023-03-07  46.91348 -110.85360    MT
# 1009:MT:SNTL                 2023-03-07  46.92690 -110.90198    MT
# 1014:CO:SNTL                 2023-03-07  39.79565 -106.02802    CO
# 1015:WY:SNTL                 2023-03-07  41.40107 -107.25740    WY
# ...                                 ...       ...        ...   ...
# 981:MT:SNTL                  2023-03-07  45.24010 -109.45961    MT
# 982:WY:SNTL                  2023-03-07  44.48632 -104.41057    WY
# 985:WA:SNTL                  2023-03-07  46.23718 -117.39438    WA
# 989:ID:SNTL                  2023-03-07  46.80500 -116.85350    ID
# 990:WA:SNTL                  2023-03-07  48.87930 -121.25550    WA
#
#                        huc  ...  \
# site_id                     ...
# 1005:CO:SNTL  130100020604  ...
# 1008:MT:SNTL  100301030801  ...
# 1009:MT:SNTL  100301030801  ...
# 1014:CO:SNTL  140100010402  ...
# 1015:WY:SNTL  101800020802  ...
# ...                    ...  ...
# 981:MT:SNTL   100700060802  ...
# 982:WY:SNTL   101202030302  ...
# 985:WA:SNTL   170601030202  ...
# 989:ID:SNTL   170603061002  ...
# 990:WA:SNTL   171100050605  ...
#
#                                                       file_path  county_name  \
# site_id
# 1005:CO:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...     Costilla
# 1008:MT:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...      Meagher
# 1009:MT:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...      Meagher
# 1014:CO:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...        Grand
# 1015:WY:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...       Carbon
# ...                                                         ...          ...
# 981:MT:SNTL   /hydrodata/national_obs/point_meteorology/NRCS...       Carbon
# 982:WY:SNTL   /hydrodata/national_obs/point_meteorology/NRCS...        Crook
# 985:WA:SNTL   /hydrodata/national_obs/point_meteorology/NRCS...       Asotin
# 989:ID:SNTL   /hydrodata/national_obs/point_meteorology/NRCS...        Latah
# 990:WA:SNTL   /hydrodata/national_obs/point_meteorology/NRCS...      Whatcom
#
#              elevation  shef_id acton_id conus1_x  conus1_y  conus2_x  \
# site_id
# 1005:CO:SNTL   10734.0    UTCC2   05M17S   1063.0     495.0      1490
# 1008:MT:SNTL    7410.0    ONPM8   10C22S    753.0    1575.0      1196
# 1009:MT:SNTL    6550.0    STCM8   10C23S    750.0    1577.0      1193
# 1014:CO:SNTL    8969.0    MFKC2   06K12S   1032.0     740.0      1461
# 1015:WY:SNTL    7850.0    SGBW4   07H06S    950.0     929.0      1381
# ...                ...      ...      ...      ...       ...       ...
# 981:MT:SNTL     5880.0    BMTM8   09D21S    831.0    1374.0      1269
# 982:WY:SNTL     5910.0    CLCW4   04E07S   1217.0    1243.0      1641
# 985:WA:SNTL     4000.0    SGUW1   17C06S    245.0    1601.0       709
# 989:ID:SNTL     4700.0    MSCI1   16C02S    300.0    1653.0       763
# 990:WA:SNTL     3630.0    BVPW1   21A01S      NaN       NaN       518
#
#              conus2_y num_obs
# site_id
# 1005:CO:SNTL     1448     365
# 1008:MT:SNTL     2499     365
# 1009:MT:SNTL     2501     365
# 1014:CO:SNTL     1689     365
# 1015:WY:SNTL     1872     365
# ...               ...     ...
# 981:MT:SNTL      2305     365
# 982:WY:SNTL      2177     365
# 985:WA:SNTL      2531     365
# 989:ID:SNTL      2580     365
# 990:WA:SNTL      2881     365
#
# [291 rows x 33 columns]

# %% [markdown]
# # 2. Read in CW3E forcing and organize

# %% [markdown]
# ### CW3E (CONUS2 Forcing)

# %%
# make CONUS2 x and y into arrays for the for loop
conusy = np.asarray(metadata['conus1_y'],dtype = 'int')
conusx = np.asarray(metadata['conus1_x'],dtype = 'int')

# %% [markdown]
# #### Read in pfb and extract data at each CONUS2 index pair included in the observations/metadata files
# *** You should only have to do this one time for each variable. The saved CSVs from this section are read back in in Section 3.

# %%
# temperature
# Set up arrays 
pf_full_array = np.zeros((no_days, ny, nx))
pf_matched = np.zeros(obs_data.shape)

### READ STREAMFLOW PFBs ###
#Read in CONUS2 daily streamflow PFBs and save as df in flow_df, convert to total accumulated in m^3/h to mean daily in cms
for i in range(no_days):
    step = str(int(i+1)).rjust(3, '0')
    ### CHECK THIS PATH TO CONFIRM CORRECT OBS FILE ###
    pf_pfb = np.squeeze(read_pfb(f'{pfb_read_path}/{pfb_name}.{step}.pfb')) 
    pf_full_array[i,...] = pf_pfb
    print(f'reading {variable} for day {step} in WY{water_year}')
    for j in range(len(obs_data.index)):
        if conusy[j] < 0:
            pf_matched[j] = 'nan'
            #print('Gage is outside of CONUS2 range')
        else:
            pf_matched[j,i] = pf_full_array[i, conusy[j], conusx[j]]
            #print('Finding value in CONUS2 grid')
# Out:
# reading Temp_C for day 001 in WY2003
# reading Temp_C for day 002 in WY2003
# reading Temp_C for day 003 in WY2003
# reading Temp_C for day 004 in WY2003
# reading Temp_C for day 005 in WY2003
# reading Temp_C for day 006 in WY2003
# reading Temp_C for day 007 in WY2003
# reading Temp_C for day 008 in WY2003
# reading Temp_C for day 009 in WY2003
# reading Temp_C for day 010 in WY2003
# reading Temp_C for day 011 in WY2003
# reading Temp_C for day 012 in WY2003
# reading Temp_C for day 013 in WY2003
# reading Temp_C for day 014 in WY2003
# reading Temp_C for day 015 in WY2003
# reading Temp_C for day 016 in WY2003
# reading Temp_C for day 017 in WY2003
# reading Temp_C for day 018 in WY2003
# reading Temp_C for day 019 in WY2003
# reading Temp_C for day 020 in WY2003
# reading Temp_C for day 021 in WY2003
# reading Temp_C for day 022 in WY2003
# reading Temp_C for day 023 in WY2003
# reading Temp_C for day 024 in WY2003
# reading Temp_C for day 025 in WY2003
# reading Temp_C for day 026 in WY2003
# reading Temp_C for day 027 in WY2003
# reading Temp_C for day 028 in WY2003
# reading Temp_C for day 029 in WY2003
# reading Temp_C for day 030 in WY2003
# reading Temp_C for day 031 in WY2003
# reading Temp_C for day 032 in WY2003
# reading Temp_C for day 033 in WY2003
# reading Temp_C for day 034 in WY2003
# reading Temp_C for day 035 in WY2003
# reading Temp_C for day 036 in WY2003
# reading Temp_C for day 037 in WY2003
# reading Temp_C for day 038 in WY2003
# reading Temp_C for day 039 in WY2003
# reading Temp_C for day 040 in WY2003
# reading Temp_C for day 041 in WY2003
# reading Temp_C for day 042 in WY2003
# reading Temp_C for day 043 in WY2003
# reading Temp_C for day 044 in WY2003
# reading Temp_C for day 045 in WY2003
# reading Temp_C for day 046 in WY2003
# reading Temp_C for day 047 in WY2003
# reading Temp_C for day 048 in WY2003
# reading Temp_C for day 049 in WY2003
# reading Temp_C for day 050 in WY2003
# reading Temp_C for day 051 in WY2003
# reading Temp_C for day 052 in WY2003
# reading Temp_C for day 053 in WY2003
# reading Temp_C for day 054 in WY2003
# reading Temp_C for day 055 in WY2003
# reading Temp_C for day 056 in WY2003
# reading Temp_C for day 057 in WY2003
# reading Temp_C for day 058 in WY2003
# reading Temp_C for day 059 in WY2003
# reading Temp_C for day 060 in WY2003
# reading Temp_C for day 061 in WY2003
# reading Temp_C for day 062 in WY2003
# reading Temp_C for day 063 in WY2003
# reading Temp_C for day 064 in WY2003
# reading Temp_C for day 065 in WY2003
# reading Temp_C for day 066 in WY2003
# reading Temp_C for day 067 in WY2003
# reading Temp_C for day 068 in WY2003
# reading Temp_C for day 069 in WY2003
# reading Temp_C for day 070 in WY2003
# reading Temp_C for day 071 in WY2003
# reading Temp_C for day 072 in WY2003
# reading Temp_C for day 073 in WY2003
# reading Temp_C for day 074 in WY2003
# reading Temp_C for day 075 in WY2003
# reading Temp_C for day 076 in WY2003
# reading Temp_C for day 077 in WY2003
# reading Temp_C for day 078 in WY2003
# reading Temp_C for day 079 in WY2003
# reading Temp_C for day 080 in WY2003
# reading Temp_C for day 081 in WY2003
# reading Temp_C for day 082 in WY2003
# reading Temp_C for day 083 in WY2003
# reading Temp_C for day 084 in WY2003
# reading Temp_C for day 085 in WY2003
# reading Temp_C for day 086 in WY2003
# reading Temp_C for day 087 in WY2003
# reading Temp_C for day 088 in WY2003
# reading Temp_C for day 089 in WY2003
# reading Temp_C for day 090 in WY2003
# reading Temp_C for day 091 in WY2003
# reading Temp_C for day 092 in WY2003
# reading Temp_C for day 093 in WY2003
# reading Temp_C for day 094 in WY2003
# reading Temp_C for day 095 in WY2003
# reading Temp_C for day 096 in WY2003
# reading Temp_C for day 097 in WY2003
# reading Temp_C for day 098 in WY2003
# reading Temp_C for day 099 in WY2003
# reading Temp_C for day 100 in WY2003
# reading Temp_C for day 101 in WY2003
# reading Temp_C for day 102 in WY2003
# reading Temp_C for day 103 in WY2003
# reading Temp_C for day 104 in WY2003
# reading Temp_C for day 105 in WY2003
# reading Temp_C for day 106 in WY2003
# reading Temp_C for day 107 in WY2003
# reading Temp_C for day 108 in WY2003
# reading Temp_C for day 109 in WY2003
# reading Temp_C for day 110 in WY2003
# reading Temp_C for day 111 in WY2003
# reading Temp_C for day 112 in WY2003
# reading Temp_C for day 113 in WY2003
# reading Temp_C for day 114 in WY2003
# reading Temp_C for day 115 in WY2003
# reading Temp_C for day 116 in WY2003
# reading Temp_C for day 117 in WY2003
# reading Temp_C for day 118 in WY2003
# reading Temp_C for day 119 in WY2003
# reading Temp_C for day 120 in WY2003
# reading Temp_C for day 121 in WY2003
# reading Temp_C for day 122 in WY2003
# reading Temp_C for day 123 in WY2003
# reading Temp_C for day 124 in WY2003
# reading Temp_C for day 125 in WY2003
# reading Temp_C for day 126 in WY2003
# reading Temp_C for day 127 in WY2003
# reading Temp_C for day 128 in WY2003
# reading Temp_C for day 129 in WY2003
# reading Temp_C for day 130 in WY2003
# reading Temp_C for day 131 in WY2003
# reading Temp_C for day 132 in WY2003
# reading Temp_C for day 133 in WY2003
# reading Temp_C for day 134 in WY2003
# reading Temp_C for day 135 in WY2003
# reading Temp_C for day 136 in WY2003
# reading Temp_C for day 137 in WY2003
# reading Temp_C for day 138 in WY2003
# reading Temp_C for day 139 in WY2003
# reading Temp_C for day 140 in WY2003
# reading Temp_C for day 141 in WY2003
# reading Temp_C for day 142 in WY2003
# reading Temp_C for day 143 in WY2003
# reading Temp_C for day 144 in WY2003
# reading Temp_C for day 145 in WY2003
# reading Temp_C for day 146 in WY2003
# reading Temp_C for day 147 in WY2003
# reading Temp_C for day 148 in WY2003
# reading Temp_C for day 149 in WY2003
# reading Temp_C for day 150 in WY2003
# reading Temp_C for day 151 in WY2003
# reading Temp_C for day 152 in WY2003
# reading Temp_C for day 153 in WY2003
# reading Temp_C for day 154 in WY2003
# reading Temp_C for day 155 in WY2003
# reading Temp_C for day 156 in WY2003
# reading Temp_C for day 157 in WY2003
# reading Temp_C for day 158 in WY2003
# reading Temp_C for day 159 in WY2003
# reading Temp_C for day 160 in WY2003
# reading Temp_C for day 161 in WY2003
# reading Temp_C for day 162 in WY2003
# reading Temp_C for day 163 in WY2003
# reading Temp_C for day 164 in WY2003
# reading Temp_C for day 165 in WY2003
# reading Temp_C for day 166 in WY2003
# reading Temp_C for day 167 in WY2003
# reading Temp_C for day 168 in WY2003
# reading Temp_C for day 169 in WY2003
# reading Temp_C for day 170 in WY2003
# reading Temp_C for day 171 in WY2003
# reading Temp_C for day 172 in WY2003
# reading Temp_C for day 173 in WY2003
# reading Temp_C for day 174 in WY2003
# reading Temp_C for day 175 in WY2003
# reading Temp_C for day 176 in WY2003
# reading Temp_C for day 177 in WY2003
# reading Temp_C for day 178 in WY2003
# reading Temp_C for day 179 in WY2003
# reading Temp_C for day 180 in WY2003
# reading Temp_C for day 181 in WY2003
# reading Temp_C for day 182 in WY2003
# reading Temp_C for day 183 in WY2003
# reading Temp_C for day 184 in WY2003
# reading Temp_C for day 185 in WY2003
# reading Temp_C for day 186 in WY2003
# reading Temp_C for day 187 in WY2003
# reading Temp_C for day 188 in WY2003
# reading Temp_C for day 189 in WY2003
# reading Temp_C for day 190 in WY2003
# reading Temp_C for day 191 in WY2003
# reading Temp_C for day 192 in WY2003
# reading Temp_C for day 193 in WY2003
# reading Temp_C for day 194 in WY2003
# reading Temp_C for day 195 in WY2003
# reading Temp_C for day 196 in WY2003
# reading Temp_C for day 197 in WY2003
# reading Temp_C for day 198 in WY2003
# reading Temp_C for day 199 in WY2003
# reading Temp_C for day 200 in WY2003
# reading Temp_C for day 201 in WY2003
# reading Temp_C for day 202 in WY2003
# reading Temp_C for day 203 in WY2003
# reading Temp_C for day 204 in WY2003
# reading Temp_C for day 205 in WY2003
# reading Temp_C for day 206 in WY2003
# reading Temp_C for day 207 in WY2003
# reading Temp_C for day 208 in WY2003
# reading Temp_C for day 209 in WY2003
# reading Temp_C for day 210 in WY2003
# reading Temp_C for day 211 in WY2003
# reading Temp_C for day 212 in WY2003
# reading Temp_C for day 213 in WY2003
# reading Temp_C for day 214 in WY2003
# reading Temp_C for day 215 in WY2003
# reading Temp_C for day 216 in WY2003
# reading Temp_C for day 217 in WY2003
# reading Temp_C for day 218 in WY2003
# reading Temp_C for day 219 in WY2003
# reading Temp_C for day 220 in WY2003
# reading Temp_C for day 221 in WY2003
# reading Temp_C for day 222 in WY2003
# reading Temp_C for day 223 in WY2003
# reading Temp_C for day 224 in WY2003
# reading Temp_C for day 225 in WY2003
# reading Temp_C for day 226 in WY2003
# reading Temp_C for day 227 in WY2003
# reading Temp_C for day 228 in WY2003
# reading Temp_C for day 229 in WY2003
# reading Temp_C for day 230 in WY2003
# reading Temp_C for day 231 in WY2003
# reading Temp_C for day 232 in WY2003
# reading Temp_C for day 233 in WY2003
# reading Temp_C for day 234 in WY2003
# reading Temp_C for day 235 in WY2003
# reading Temp_C for day 236 in WY2003
# reading Temp_C for day 237 in WY2003
# reading Temp_C for day 238 in WY2003
# reading Temp_C for day 239 in WY2003
# reading Temp_C for day 240 in WY2003
# reading Temp_C for day 241 in WY2003
# reading Temp_C for day 242 in WY2003
# reading Temp_C for day 243 in WY2003
# reading Temp_C for day 244 in WY2003
# reading Temp_C for day 245 in WY2003
# reading Temp_C for day 246 in WY2003
# reading Temp_C for day 247 in WY2003
# reading Temp_C for day 248 in WY2003
# reading Temp_C for day 249 in WY2003
# reading Temp_C for day 250 in WY2003
# reading Temp_C for day 251 in WY2003
# reading Temp_C for day 252 in WY2003
# reading Temp_C for day 253 in WY2003
# reading Temp_C for day 254 in WY2003
# reading Temp_C for day 255 in WY2003
# reading Temp_C for day 256 in WY2003
# reading Temp_C for day 257 in WY2003
# reading Temp_C for day 258 in WY2003
# reading Temp_C for day 259 in WY2003
# reading Temp_C for day 260 in WY2003
# reading Temp_C for day 261 in WY2003
# reading Temp_C for day 262 in WY2003
# reading Temp_C for day 263 in WY2003
# reading Temp_C for day 264 in WY2003
# reading Temp_C for day 265 in WY2003
# reading Temp_C for day 266 in WY2003
# reading Temp_C for day 267 in WY2003
# reading Temp_C for day 268 in WY2003
# reading Temp_C for day 269 in WY2003
# reading Temp_C for day 270 in WY2003
# reading Temp_C for day 271 in WY2003
# reading Temp_C for day 272 in WY2003
# reading Temp_C for day 273 in WY2003
# reading Temp_C for day 274 in WY2003
# reading Temp_C for day 275 in WY2003
# reading Temp_C for day 276 in WY2003
# reading Temp_C for day 277 in WY2003
# reading Temp_C for day 278 in WY2003
# reading Temp_C for day 279 in WY2003
# reading Temp_C for day 280 in WY2003
# reading Temp_C for day 281 in WY2003
# reading Temp_C for day 282 in WY2003
# reading Temp_C for day 283 in WY2003
# reading Temp_C for day 284 in WY2003
# reading Temp_C for day 285 in WY2003
# reading Temp_C for day 286 in WY2003
# reading Temp_C for day 287 in WY2003
# reading Temp_C for day 288 in WY2003
# reading Temp_C for day 289 in WY2003
# reading Temp_C for day 290 in WY2003
# reading Temp_C for day 291 in WY2003
# reading Temp_C for day 292 in WY2003
# reading Temp_C for day 293 in WY2003
# reading Temp_C for day 294 in WY2003
# reading Temp_C for day 295 in WY2003
# reading Temp_C for day 296 in WY2003
# reading Temp_C for day 297 in WY2003
# reading Temp_C for day 298 in WY2003
# reading Temp_C for day 299 in WY2003
# reading Temp_C for day 300 in WY2003
# reading Temp_C for day 301 in WY2003
# reading Temp_C for day 302 in WY2003
# reading Temp_C for day 303 in WY2003
# reading Temp_C for day 304 in WY2003
# reading Temp_C for day 305 in WY2003
# reading Temp_C for day 306 in WY2003
# reading Temp_C for day 307 in WY2003
# reading Temp_C for day 308 in WY2003
# reading Temp_C for day 309 in WY2003
# reading Temp_C for day 310 in WY2003
# reading Temp_C for day 311 in WY2003
# reading Temp_C for day 312 in WY2003
# reading Temp_C for day 313 in WY2003
# reading Temp_C for day 314 in WY2003
# reading Temp_C for day 315 in WY2003
# reading Temp_C for day 316 in WY2003
# reading Temp_C for day 317 in WY2003
# reading Temp_C for day 318 in WY2003
# reading Temp_C for day 319 in WY2003
# reading Temp_C for day 320 in WY2003
# reading Temp_C for day 321 in WY2003
# reading Temp_C for day 322 in WY2003
# reading Temp_C for day 323 in WY2003
# reading Temp_C for day 324 in WY2003
# reading Temp_C for day 325 in WY2003
# reading Temp_C for day 326 in WY2003
# reading Temp_C for day 327 in WY2003
# reading Temp_C for day 328 in WY2003
# reading Temp_C for day 329 in WY2003
# reading Temp_C for day 330 in WY2003
# reading Temp_C for day 331 in WY2003
# reading Temp_C for day 332 in WY2003
# reading Temp_C for day 333 in WY2003
# reading Temp_C for day 334 in WY2003
# reading Temp_C for day 335 in WY2003
# reading Temp_C for day 336 in WY2003
# reading Temp_C for day 337 in WY2003
# reading Temp_C for day 338 in WY2003
# reading Temp_C for day 339 in WY2003
# reading Temp_C for day 340 in WY2003
# reading Temp_C for day 341 in WY2003
# reading Temp_C for day 342 in WY2003
# reading Temp_C for day 343 in WY2003
# reading Temp_C for day 344 in WY2003
# reading Temp_C for day 345 in WY2003
# reading Temp_C for day 346 in WY2003
# reading Temp_C for day 347 in WY2003
# reading Temp_C for day 348 in WY2003
# reading Temp_C for day 349 in WY2003
# reading Temp_C for day 350 in WY2003
# reading Temp_C for day 351 in WY2003
# reading Temp_C for day 352 in WY2003
# reading Temp_C for day 353 in WY2003
# reading Temp_C for day 354 in WY2003
# reading Temp_C for day 355 in WY2003
# reading Temp_C for day 356 in WY2003
# reading Temp_C for day 357 in WY2003
# reading Temp_C for day 358 in WY2003
# reading Temp_C for day 359 in WY2003
# reading Temp_C for day 360 in WY2003
# reading Temp_C for day 361 in WY2003
# reading Temp_C for day 362 in WY2003
# reading Temp_C for day 363 in WY2003
# reading Temp_C for day 364 in WY2003
# reading Temp_C for day 365 in WY2003

# %%
# Organize PF daily matched array with the same index and dates as the obs_data
pf_match_df = pd.DataFrame(pf_matched)
pf_match_df = pf_match_df.set_index(obs_data.index)
column_headers = list(obs_data.columns.values)
pf_match_df.columns = column_headers

# %%
# drop any na's and convert temperature
pf_match_df_new = pf_match_df.dropna()
pf_match_df_new = pf_match_df_new-273.15 #convert 
pf_match_df_new
# Out:
#               2002-10-01  2002-10-02  2002-10-03  2002-10-04  2002-10-05  \
# site_id
# 1005:CO:SNTL    6.491401    5.621702    3.070619    0.589253    4.353047
# 1008:MT:SNTL   -2.353215   -2.709176    0.773314    0.757912    1.409868
# 1009:MT:SNTL   -1.906147   -2.258849    1.181675    1.217188    1.874785
# 1014:CO:SNTL    5.240891    4.176604    2.735162   -0.137419    1.559038
# 1015:WY:SNTL    8.507589    5.619287    4.161377    3.713605    4.887420
# ...                  ...         ...         ...         ...         ...
# 978:ID:SNTL     2.463088    2.616257    3.976962    7.057055    7.079333
# 981:MT:SNTL     3.618739    2.322970    3.191755    4.378183    5.226171
# 982:WY:SNTL     6.053237    2.256146    3.430009    4.854360    5.613485
# 985:WA:SNTL     6.679914    6.891303    8.688061    9.490172   10.383010
# 989:ID:SNTL     6.929308    6.999317    7.980815    8.040379   10.064692
#
#               2002-10-06  2002-10-07  2002-10-08  2002-10-09  2002-10-10  ...  \
# site_id                                                                   ...
# 1005:CO:SNTL    5.016395    6.123093    7.032209    5.340531    6.476659  ...
# 1008:MT:SNTL    2.255271    5.963503    4.239907    2.976448    4.322897  ...
# 1009:MT:SNTL    2.724943    6.409685    4.728506    3.342274    4.697242  ...
# 1014:CO:SNTL    3.048592    4.433263    4.828235    2.835054    3.318273  ...
# 1015:WY:SNTL    6.425308    7.524670    8.504357    7.415909    8.752585  ...
# ...                  ...         ...         ...         ...         ...  ...
# 978:ID:SNTL     7.743472    9.591494    8.903088    8.304622    9.160127  ...
# 981:MT:SNTL     6.253805    8.584214    8.697566    6.877124    8.492423  ...
# 982:WY:SNTL     4.637332    8.797248    7.951697    7.032446   10.172374  ...
# 985:WA:SNTL    11.630551   12.958760   12.713981   11.041217    9.072581  ...
# 989:ID:SNTL    11.149913   11.714614   12.435336   10.442838    8.538765  ...
#
#               2003-09-21  2003-09-22  2003-09-23  2003-09-24  2003-09-25  \
# site_id
# 1005:CO:SNTL    8.167336    8.944457   10.715746   11.246580   10.024764
# 1008:MT:SNTL    4.676308    5.676641    9.733144    5.190211   10.007316
# 1009:MT:SNTL    5.122761    6.130095   10.149117    5.699717   10.489893
# 1014:CO:SNTL    5.729832    7.212628    9.350711    9.432102    9.148492
# 1015:WY:SNTL    9.887712   11.075861   13.411918   12.960523   13.304853
# ...                  ...         ...         ...         ...         ...
# 978:ID:SNTL    11.395935   12.449758   15.801538   14.693580   15.482402
# 981:MT:SNTL     8.876877   10.255052   14.208142   11.512895   13.393866
# 982:WY:SNTL     8.333728    7.195111   14.234885    7.853941    9.334702
# 985:WA:SNTL    12.852580   14.309684   16.205836   15.810082   17.568830
# 989:ID:SNTL    12.625898   13.731168   15.378186   14.921721   17.177916
#
#               2003-09-26  2003-09-27  2003-09-28  2003-09-29  2003-09-30
# site_id
# 1005:CO:SNTL   11.227979    9.949922    8.895284   10.093548    8.828307
# 1008:MT:SNTL   10.278127    7.330887    5.350956    3.534269    2.359674
# 1009:MT:SNTL   10.747402    7.836608    5.851549    3.998923    2.873811
# 1014:CO:SNTL   10.496759    8.519245    8.185311    8.768264    8.672646
# 1015:WY:SNTL   14.621777   12.644356   11.248159   11.502303    9.982086
# ...                  ...         ...         ...         ...         ...
# 978:ID:SNTL    15.269921   15.816656   17.151428   18.037831   17.742222
# 981:MT:SNTL    14.053597   11.924092   10.295051    8.836849    8.535953
# 982:WY:SNTL    11.602343    7.683814    6.424729    5.292132    3.902512
# 985:WA:SNTL    18.233436   18.151636   18.490152   18.756926   17.022688
# 989:ID:SNTL    17.315300   17.562954   17.806356   17.740814   15.417310
#
# [244 rows x 365 columns]

# %%
# parse down observation df to include the same stations as the final ParFlow matched df
obs_data_new = obs_data[obs_data.index.isin(pf_match_df_new.index)]
obs_data_new
# Out:
#               2002-10-01  2002-10-02  2002-10-03  2002-10-04  2002-10-05  \
# site_id
# 1005:CO:SNTL         5.2         3.4         0.6         1.8         5.0
# 1008:MT:SNTL        -2.9        -1.0        -0.3         0.6        -0.1
# 1009:MT:SNTL        -1.2        -0.4         0.6         2.0         1.3
# 1014:CO:SNTL         5.3         4.9         1.1         1.9         3.0
# 1015:WY:SNTL         6.6         4.2         1.9         2.8         4.8
# ...                  ...         ...         ...         ...         ...
# 978:ID:SNTL          2.3         4.3         6.1         6.3         6.6
# 981:MT:SNTL         -0.2         0.6         3.1         4.4         5.9
# 982:WY:SNTL          1.9         0.0         4.0         2.5         3.4
# 985:WA:SNTL          5.6         7.8         7.9         8.7        10.3
# 989:ID:SNTL          3.9         5.8         5.1         6.8         6.8
#
#               2002-10-06  2002-10-07  2002-10-08  2002-10-09  2002-10-10  ...  \
# site_id                                                                   ...
# 1005:CO:SNTL         3.5         3.8         3.5         4.9         4.5  ...
# 1008:MT:SNTL         2.5         5.3         2.7         4.8         5.4  ...
# 1009:MT:SNTL         3.1         5.4         3.1         3.7         5.3  ...
# 1014:CO:SNTL         3.1         4.5         4.1         3.7         4.9  ...
# 1015:WY:SNTL         6.6         8.3         7.3         8.0         9.9  ...
# ...                  ...         ...         ...         ...         ...  ...
# 978:ID:SNTL          9.2         9.5         7.5         7.9         7.9  ...
# 981:MT:SNTL          8.2        12.0         7.0        11.2        13.6  ...
# 982:WY:SNTL          2.9         8.5         4.1         8.3        12.0  ...
# 985:WA:SNTL         13.0        13.6        12.4        12.0         6.8  ...
# 989:ID:SNTL          9.3        10.7        10.1         9.2         4.1  ...
#
#               2003-09-21  2003-09-22  2003-09-23  2003-09-24  2003-09-25  \
# site_id
# 1005:CO:SNTL         6.1         7.1         9.4         7.5         7.6
# 1008:MT:SNTL         2.1         8.2         7.8         5.7        11.4
# 1009:MT:SNTL         2.5         8.0         8.9         6.3        11.9
# 1014:CO:SNTL         5.0         6.2         7.4         7.0         7.1
# 1015:WY:SNTL         8.5        11.1        13.5        12.3        13.5
# ...                  ...         ...         ...         ...         ...
# 978:ID:SNTL         11.3        12.5        13.1        13.6        14.8
# 981:MT:SNTL          7.6        13.5        14.0         8.7        19.8
# 982:WY:SNTL          7.0         9.4        13.1         4.9        12.6
# 985:WA:SNTL         13.4        16.7        16.6        17.3        19.8
# 989:ID:SNTL         11.2        13.3        13.4        14.8        15.6
#
#               2003-09-26  2003-09-27  2003-09-28  2003-09-29  2003-09-30
# site_id
# 1005:CO:SNTL         9.0         8.7         6.7         8.0         7.6
# 1008:MT:SNTL         7.9         5.9         5.5         2.4         4.2
# 1009:MT:SNTL         8.0         6.0         6.0         3.3         3.9
# 1014:CO:SNTL         7.9         7.0         7.5         8.3         8.3
# 1015:WY:SNTL        12.9        10.4         8.5         8.3         6.7
# ...                  ...         ...         ...         ...         ...
# 978:ID:SNTL         18.1        16.2        15.7        15.8        15.5
# 981:MT:SNTL         12.1        10.2         9.3         5.3         7.5
# 982:WY:SNTL          6.6         6.7         5.5         2.7         4.1
# 985:WA:SNTL         19.7        19.4        19.7        17.2        16.7
# 989:ID:SNTL         16.7        17.3        17.7        15.4        18.2
#
# [244 rows x 365 columns]

# %%
# parse down metadata df to include the same stations as the final ParFlow matched df
metadata_new = metadata[metadata.index.isin(pf_match_df_new.index)]
metadata_new
# Out:
#                    site_type agency         site_name site_id_agency  \
# site_id
# 1005:CO:SNTL  SNOTEL station   NRCS         Ute Creek   1005:CO:SNTL
# 1008:MT:SNTL  SNOTEL station   NRCS        Onion Park   1008:MT:SNTL
# 1009:MT:SNTL  SNOTEL station   NRCS    Stringer Creek   1009:MT:SNTL
# 1014:CO:SNTL  SNOTEL station   NRCS  Middle Fork Camp   1014:CO:SNTL
# 1015:WY:SNTL  SNOTEL station   NRCS  Sage Creek Basin   1015:WY:SNTL
# ...                      ...    ...               ...            ...
# 978:ID:SNTL   SNOTEL station   NRCS       Bogus Basin    978:ID:SNTL
# 981:MT:SNTL   SNOTEL station   NRCS         Burnt Mtn    981:MT:SNTL
# 982:WY:SNTL   SNOTEL station   NRCS       Cole Canyon    982:WY:SNTL
# 985:WA:SNTL   SNOTEL station   NRCS   Sourdough Gulch    985:WA:SNTL
# 989:ID:SNTL   SNOTEL station   NRCS   Moscow Mountain    989:ID:SNTL
#
#                                                  site_query_url  \
# site_id
# 1005:CO:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 1008:MT:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 1009:MT:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 1014:CO:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 1015:WY:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# ...                                                         ...
# 978:ID:SNTL   https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 981:MT:SNTL   https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 982:WY:SNTL   https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 985:WA:SNTL   https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 989:ID:SNTL   https://wcc.sc.egov.usda.gov/awdbWebService/we...
#
#              date_metadata_last_updated  latitude  longitude state  \
# site_id
# 1005:CO:SNTL                 2023-03-07  37.61480 -105.37322    CO
# 1008:MT:SNTL                 2023-03-07  46.91348 -110.85360    MT
# 1009:MT:SNTL                 2023-03-07  46.92690 -110.90198    MT
# 1014:CO:SNTL                 2023-03-07  39.79565 -106.02802    CO
# 1015:WY:SNTL                 2023-03-07  41.40107 -107.25740    WY
# ...                                 ...       ...        ...   ...
# 978:ID:SNTL                  2023-03-07  43.76377 -116.09685    ID
# 981:MT:SNTL                  2023-03-07  45.24010 -109.45961    MT
# 982:WY:SNTL                  2023-03-07  44.48632 -104.41057    WY
# 985:WA:SNTL                  2023-03-07  46.23718 -117.39438    WA
# 989:ID:SNTL                  2023-03-07  46.80500 -116.85350    ID
#
#                        huc  ...  \
# site_id                     ...
# 1005:CO:SNTL  130100020604  ...
# 1008:MT:SNTL  100301030801  ...
# 1009:MT:SNTL  100301030801  ...
# 1014:CO:SNTL  140100010402  ...
# 1015:WY:SNTL  101800020802  ...
# ...                    ...  ...
# 978:ID:SNTL   170501220201  ...
# 981:MT:SNTL   100700060802  ...
# 982:WY:SNTL   101202030302  ...
# 985:WA:SNTL   170601030202  ...
# 989:ID:SNTL   170603061002  ...
#
#                                                       file_path  county_name  \
# site_id
# 1005:CO:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...     Costilla
# 1008:MT:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...      Meagher
# 1009:MT:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...      Meagher
# 1014:CO:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...        Grand
# 1015:WY:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...       Carbon
# ...                                                         ...          ...
# 978:ID:SNTL   /hydrodata/national_obs/point_meteorology/NRCS...        Boise
# 981:MT:SNTL   /hydrodata/national_obs/point_meteorology/NRCS...       Carbon
# 982:WY:SNTL   /hydrodata/national_obs/point_meteorology/NRCS...        Crook
# 985:WA:SNTL   /hydrodata/national_obs/point_meteorology/NRCS...       Asotin
# 989:ID:SNTL   /hydrodata/national_obs/point_meteorology/NRCS...        Latah
#
#              elevation  shef_id acton_id conus1_x  conus1_y  conus2_x  \
# site_id
# 1005:CO:SNTL   10734.0    UTCC2   05M17S   1063.0     495.0      1490
# 1008:MT:SNTL    7410.0    ONPM8   10C22S    753.0    1575.0      1196
# 1009:MT:SNTL    6550.0    STCM8   10C23S    750.0    1577.0      1193
# 1014:CO:SNTL    8969.0    MFKC2   06K12S   1032.0     740.0      1461
# 1015:WY:SNTL    7850.0    SGBW4   07H06S    950.0     929.0      1381
# ...                ...      ...      ...      ...       ...       ...
# 978:ID:SNTL     6340.0    BOGI1   16F02S    283.0    1310.0       740
# 981:MT:SNTL     5880.0    BMTM8   09D21S    831.0    1374.0      1269
# 982:WY:SNTL     5910.0    CLCW4   04E07S   1217.0    1243.0      1641
# 985:WA:SNTL     4000.0    SGUW1   17C06S    245.0    1601.0       709
# 989:ID:SNTL     4700.0    MSCI1   16C02S    300.0    1653.0       763
#
#              conus2_y num_obs
# site_id
# 1005:CO:SNTL     1448     365
# 1008:MT:SNTL     2499     365
# 1009:MT:SNTL     2501     365
# 1014:CO:SNTL     1689     365
# 1015:WY:SNTL     1872     365
# ...               ...     ...
# 978:ID:SNTL      2249     365
# 981:MT:SNTL      2305     365
# 982:WY:SNTL      2177     365
# 985:WA:SNTL      2531     365
# 989:ID:SNTL      2580     365
#
# [244 rows x 33 columns]

# %%
# save the newly matched daily average, observations, and metadata as csv's
pf_match_df_new.to_csv(f'{organized_dir}/{pf_matched_csv}', sep = ",")
obs_data_new.to_csv(f'{organized_dir}/{snotel_matched_csv}', sep = ",")
metadata_new.to_csv(f'{organized_dir}/{metadata_matched_csv}', sep = ",")

# %% [markdown]
# # 3. Compute and save stats

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from math import sqrt
from scipy import stats

# %%
### read in CONUS2 daily matched csv
# Temperature in C
pfdata = pd.read_csv(f'{organized_dir}/{pf_matched_csv}',index_col=['site_id'])
print(pfdata.shape)
pfdata.head()
# Out:
# (657, 365)
#               2002-10-01  2002-10-02  2002-10-03  2002-10-04  2002-10-05
# site_id
# 1000:OR:SNTL    0.452749   -0.037787    4.163962    4.602537    7.657367  \
# 1005:CO:SNTL    7.262504    5.576400    2.542334   -0.998446    1.500982
# 1006:NV:SNTL    4.305715   -0.498291   -1.082200    3.610405    3.261910
# 1008:MT:SNTL   -0.390237   -3.318083   -1.566407   -1.190700    0.375963
# 1009:MT:SNTL    0.831790   -2.273385   -0.322611   -0.231768    1.503755
#
#               2002-10-06  2002-10-07  2002-10-08  2002-10-09  2002-10-10  ...
# site_id                                                                   ...
# 1000:OR:SNTL    9.320978   11.255205   11.361138   10.214299    9.273023  ...  \
# 1005:CO:SNTL    4.885522    4.342208    5.858128    5.484463    5.503211  ...
# 1006:NV:SNTL    6.601198    9.306240   10.216397   10.762437   11.066764  ...
# 1008:MT:SNTL   -0.877002    2.052700    5.387891    2.719790    4.602048  ...
# 1009:MT:SNTL    0.481219    3.402945    6.216261    3.834474    5.532480  ...
#
#               2003-09-21  2003-09-22  2003-09-23  2003-09-24  2003-09-25
# site_id
# 1000:OR:SNTL   11.843220   13.681202   15.593554   15.734534   16.152535  \
# 1005:CO:SNTL    6.722181    6.536026    7.585606    9.684070    8.246058
# 1006:NV:SNTL   13.564827   14.817957   15.877203   17.183832   18.160396
# 1008:MT:SNTL    4.972007    2.549454    7.724030    6.847152    6.160591
# 1009:MT:SNTL    6.023805    3.669542    8.711857    8.045283    7.496431
#
#               2003-09-26  2003-09-27  2003-09-28  2003-09-29  2003-09-30
# site_id
# 1000:OR:SNTL   15.613653   18.629292   18.540018   17.434109   10.731911
# 1005:CO:SNTL    9.331012    9.133006    6.540067    6.428365    8.773644
# 1006:NV:SNTL   17.309611   17.601383   18.132715   18.499653   16.951897
# 1008:MT:SNTL   11.850128    8.385088    7.114097    6.946448    2.429783
# 1009:MT:SNTL   12.761174    9.297189    8.082850    7.956637    3.467466
#
# [5 rows x 365 columns]

# %%
### read in SNOTEL daily matched csv
# Temperature in C
snotel_data= pd.read_csv(f'{organized_dir}/{snotel_matched_csv}',index_col=['site_id']) 
print(snotel_data.shape)
snotel_data.head()
# Out:
# (657, 365)
#               2002-10-01  2002-10-02  2002-10-03  2002-10-04  2002-10-05
# site_id
# 1000:OR:SNTL         0.6         3.4         4.3         7.2         8.4  \
# 1005:CO:SNTL         5.2         3.4         0.6         1.8         5.0
# 1006:NV:SNTL         0.4         0.6         4.7         4.4         6.4
# 1008:MT:SNTL        -2.9        -1.0        -0.3         0.6        -0.1
# 1009:MT:SNTL        -1.2        -0.4         0.6         2.0         1.3
#
#               2002-10-06  2002-10-07  2002-10-08  2002-10-09  2002-10-10  ...
# site_id                                                                   ...
# 1000:OR:SNTL         8.9         9.2         8.0         6.8         2.8  ...  \
# 1005:CO:SNTL         3.5         3.8         3.5         4.9         4.5  ...
# 1006:NV:SNTL         8.6         9.7        10.0        10.8        12.2  ...
# 1008:MT:SNTL         2.5         5.3         2.7         4.8         5.4  ...
# 1009:MT:SNTL         3.1         5.4         3.1         3.7         5.3  ...
#
#               2003-09-21  2003-09-22  2003-09-23  2003-09-24  2003-09-25
# site_id
# 1000:OR:SNTL        11.8        13.1        13.3        13.9        13.5  \
# 1005:CO:SNTL         6.1         7.1         9.4         7.5         7.6
# 1006:NV:SNTL        13.9        15.1        16.3        16.7        16.0
# 1008:MT:SNTL         2.1         8.2         7.8         5.7        11.4
# 1009:MT:SNTL         2.5         8.0         8.9         6.3        11.9
#
#               2003-09-26  2003-09-27  2003-09-28  2003-09-29  2003-09-30
# site_id
# 1000:OR:SNTL        16.2        16.1        15.0         9.8         8.7
# 1005:CO:SNTL         9.0         8.7         6.7         8.0         7.6
# 1006:NV:SNTL        16.6        16.7        17.2        16.5        15.8
# 1008:MT:SNTL         7.9         5.9         5.5         2.4         4.2
# 1009:MT:SNTL         8.0         6.0         6.0         3.3         3.9
#
# [5 rows x 365 columns]

# %%
### read in SNOTEL Temperature metadata for all stations 
snotel_metadata = pd.read_csv(f'{organized_dir}/{metadata_matched_csv}',index_col=['site_id'])
print(snotel_metadata.shape)
snotel_metadata.head()
# Out:
# (657, 33)
#                    site_type agency       site_name site_id_agency
# site_id
# 1000:OR:SNTL  SNOTEL station   NRCS   Annie Springs   1000:OR:SNTL  \
# 1005:CO:SNTL  SNOTEL station   NRCS       Ute Creek   1005:CO:SNTL
# 1006:NV:SNTL  SNOTEL station   NRCS      Lewis Peak   1006:NV:SNTL
# 1008:MT:SNTL  SNOTEL station   NRCS      Onion Park   1008:MT:SNTL
# 1009:MT:SNTL  SNOTEL station   NRCS  Stringer Creek   1009:MT:SNTL
#
#                                                  site_query_url
# site_id
# 1000:OR:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...  \
# 1005:CO:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 1006:NV:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 1008:MT:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
# 1009:MT:SNTL  https://wcc.sc.egov.usda.gov/awdbWebService/we...
#
#              date_metadata_last_updated  latitude  longitude state
# site_id
# 1000:OR:SNTL                 2023-03-07  42.87007 -122.16518    OR  \
# 1005:CO:SNTL                 2023-03-07  37.61480 -105.37322    CO
# 1006:NV:SNTL                 2023-03-07  40.35720 -116.86470    NV
# 1008:MT:SNTL                 2023-03-07  46.91348 -110.85360    MT
# 1009:MT:SNTL                 2023-03-07  46.92690 -110.90198    MT
#
#                        huc  ...
# site_id                     ...
# 1000:OR:SNTL  180102030101  ...  \
# 1005:CO:SNTL  130100020604  ...
# 1006:NV:SNTL  160401070903  ...
# 1008:MT:SNTL  100301030801  ...
# 1009:MT:SNTL  100301030801  ...
#
#                                                       file_path  county_name
# site_id
# 1000:OR:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...      Klamath  \
# 1005:CO:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...     Costilla
# 1006:NV:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...       Lander
# 1008:MT:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...      Meagher
# 1009:MT:SNTL  /hydrodata/national_obs/point_meteorology/NRCS...      Meagher
#
#              elevation  shef_id acton_id conus1_x  conus1_y  conus2_x
# site_id
# 1000:OR:SNTL    6010.0    ANSO3   22G06S      NaN       NaN       258  \
# 1005:CO:SNTL   10734.0    UTCC2   05M17S   1063.0     495.0      1490
# 1006:NV:SNTL    7370.0    LWPN2   16J01S    137.0     957.0       592
# 1008:MT:SNTL    7410.0    ONPM8   10C22S    753.0    1575.0      1196
# 1009:MT:SNTL    6550.0    STCM8   10C23S    750.0    1577.0      1193
#
#              conus2_y num_obs
# site_id
# 1000:OR:SNTL     2286     364
# 1005:CO:SNTL     1448     365
# 1006:NV:SNTL     1908     363
# 1008:MT:SNTL     2499     365
# 1009:MT:SNTL     2501     365
#
# [5 rows x 33 columns]

# %%
# set up DF for daily stats, index is station site_id
stats_df = pd.DataFrame(index = snotel_metadata.index, columns = ['site_name', 'state', 'latitude', 'longitude', 'conus2_x','conus2_y']) 
#, 'bias', 'pbias','absrelbias', 'relbias','srho', 'r2', 'mse', 'rmse', 'nse',scaled RMSE

stats_df['site_name'] = snotel_metadata['site_name']
stats_df['state'] = snotel_metadata['state']
stats_df['latitude'] = snotel_metadata['latitude']
stats_df['longitude'] = snotel_metadata['longitude']
stats_df['conus2_x'] = snotel_metadata['conus2_x'].astype(int)
stats_df['conus2_y'] = snotel_metadata['conus2_y'].astype(int)
print(stats_df.shape)
stats_df.head()
# Out:
# (657, 6)
#                    site_name state  latitude  longitude  conus2_x  conus2_y
# site_id
# 1000:OR:SNTL   Annie Springs    OR  42.87007 -122.16518       258      2286
# 1005:CO:SNTL       Ute Creek    CO  37.61480 -105.37322      1490      1448
# 1006:NV:SNTL      Lewis Peak    NV  40.35720 -116.86470       592      1908
# 1008:MT:SNTL      Onion Park    MT  46.91348 -110.85360      1196      2499
# 1009:MT:SNTL  Stringer Creek    MT  46.92690 -110.90198      1193      2501

# %%
# compute annual average for observations
# calcualate "yearly average" by dividing annual sum by num_obs (note not all sites have 365 observations)
snotel_Temp_sum = snotel_data.sum(axis=1)

### CHANGE THE NAMES OF THESE COLUMN HEADERS ###
stats_df['SNOTEL_mean_T_C'] = snotel_Temp_sum/snotel_metadata.num_obs
stats_df['CW3E_mean_T_C'] = np.mean(pfdata, axis = 1)

# %%
# Set up array for stats
r2_daily = np.zeros(len(pfdata.index))
srho_daily = np.zeros(len(pfdata.index))
pval_daily = np.zeros(len(pfdata.index))
mse_daily = np.zeros(len(pfdata.index))
rmse_daily = np.zeros(len(pfdata.index))
nse_daily = np.zeros(len(pfdata.index))
bias_daily = np.zeros(len(pfdata.index))
pbias_daily = np.zeros(len(pfdata.index))
pbias_test = np.zeros(len(pfdata.index))
absrelbias_daily = np.zeros(len(pfdata.index))
relbias_daily = np.zeros(len(pfdata.index))
r2_daily.shape
# Out:
# (726,)

# %%
for g in range(len(pfdata.index)):
    gage = pfdata.index[g]
    absrelbias_daily[g] = abs((pfdata.loc[gage].sum()-snotel_data.loc[gage].sum())/snotel_data.loc[gage].sum()) #absolute relative bias
    bias_daily[g] = (pfdata.loc[gage].sum()-snotel_data.loc[gage].sum())/snotel_data.loc[gage].sum()
    pbias_daily[g] = bias_daily[g]*100
    srho_daily[g], pval_daily[g] = stats.spearmanr(snotel_data.loc[gage], pfdata.loc[gage])
    # mse_daily[g] = mean_squared_error(usgs_flow_matched.loc[gage], pf_flow_matched.loc[gage])
    #rmse_daily[g] = sqrt(mean_squared_error(snotel_data.loc[gage], pfdata.loc[gage]))
    #r2_daily[g] = r2_score(snotel_data.loc[gage], pfdata.loc[gage])

# %%
# assign arrays to pandas columns in stats_df
stats_df['absrelbias'] = absrelbias_daily
stats_df['bias'] = bias_daily
stats_df['pbias'] = pbias_daily
stats_df['srho'] = srho_daily
# stats_df['r2'] = r2_daily
# stats_df['rmse'] = rmse_daily
# stats_df['mse'] = mse_daily

# %%
stats_df.head()
# Out:
#                    site_name state  latitude  longitude  conus2_x  conus2_y  \
# site_id
# 1000:OR:SNTL   Annie Springs    OR  42.87007 -122.16518       258      2286
# 1005:CO:SNTL       Ute Creek    CO  37.61480 -105.37322      1490      1448
# 1006:NV:SNTL      Lewis Peak    NV  40.35720 -116.86470       592      1908
# 1008:MT:SNTL      Onion Park    MT  46.91348 -110.85360      1196      2499
# 1009:MT:SNTL  Stringer Creek    MT  46.92690 -110.90198      1193      2501
#
#               SNOTEL_mean_T_C  CW3E_mean_T_C  absrelbias      bias      pbias  \
# site_id
# 1000:OR:SNTL         4.798356       5.082888    0.059298  0.059298   5.929785
# 1005:CO:SNTL         1.762637       2.298566    0.307632  0.307632  30.763207
# 1006:NV:SNTL         6.578761       6.505617    0.064725  0.064725   6.472517
# 1008:MT:SNTL         2.293973       1.836576    0.199390 -0.199390 -19.939043
# 1009:MT:SNTL         2.570685       2.763530    0.075017  0.075017   7.501694
#
#                   srho
# site_id
# 1000:OR:SNTL  0.932154
# 1005:CO:SNTL       NaN
# 1006:NV:SNTL       NaN
# 1008:MT:SNTL  0.910986
# 1009:MT:SNTL  0.923139

# %%
stats_df.to_csv(f'{organized_dir}/{summary_stats_csv}')

# %% [markdown]
# # 4. Plotting Results

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
#from mpl_toolkits.basemap import Basemap as Basemap

# %%
summary_plot_dir = 'summary_plots_temperature'
timeseries_plot_dir = 'Timeseries_2004_Temp_SNOTEL'

# %%
### read in USGS daily flow matched csv
stats_df = pd.read_csv(f'{organized_dir}/{summary_stats_csv}',index_col=['site_id']) 
# select stations within reasonable range and remove a couple SNOTEL stations with errors (temperatures>100C)
stats_df = stats_df.where(stats_df['SNOTEL_mean_T_C']< 45, 'nan')
#stats_df = stats_df[stats_df.SNOTEL_mean_T_C > int(-20)]
stats_df.head()
type(stats_df['SNOTEL_mean_T_C'])
# Out:
# pandas.core.series.Series

# %%
stats_df['num_obs'] = snotel_metadata['num_obs']
stats_df.shape
# Out:
# (657, 13)

# %%
stats_df
# Out:
#                     site_name state  latitude  longitude conus2_x conus2_y
# site_id
# 1000:OR:SNTL    Annie Springs    OR  42.87007 -122.16518      258     2286  \
# 1005:CO:SNTL        Ute Creek    CO   37.6148 -105.37322     1490     1448
# 1006:NV:SNTL       Lewis Peak    NV   40.3572  -116.8647      592     1908
# 1008:MT:SNTL       Onion Park    MT  46.91348  -110.8536     1196     2499
# 1009:MT:SNTL   Stringer Creek    MT   46.9269 -110.90198     1193     2501
# ...                       ...   ...       ...        ...      ...      ...
# 985:WA:SNTL   Sourdough Gulch    WA  46.23718 -117.39438      709     2531
# 988:ID:SNTL       Hidden Lake    ID   48.8937 -116.75748      825     2796
# 989:ID:SNTL   Moscow Mountain    ID    46.805  -116.8535      763     2580
# 990:WA:SNTL       Beaver Pass    WA   48.8793  -121.2555      518     2881
# 991:WA:SNTL     Hozomeen Camp    WA  48.98075 -121.07976      533     2887
#
#              SNOTEL_mean_T_C CW3E_mean_T_C absrelbias      bias      pbias
# site_id
# 1000:OR:SNTL         5.17967      5.368766   0.039355  0.039355   3.935488  \
# 1005:CO:SNTL        1.915616      2.125367   0.109495  0.109495  10.949511
# 1006:NV:SNTL        7.539669      7.100707   0.053032 -0.053032   -5.30315
# 1008:MT:SNTL        2.255068      1.927708   0.145166 -0.145166 -14.516645
# 1009:MT:SNTL        2.508493      2.844596   0.133986  0.133986  13.398577
# ...                      ...           ...        ...       ...        ...
# 985:WA:SNTL         9.649863      9.345262   0.031565 -0.031565  -3.156528
# 988:ID:SNTL          4.73956      4.505746   0.046721 -0.046721  -4.672079
# 989:ID:SNTL         7.090137      6.198236   0.125795 -0.125795 -12.579455
# 990:WA:SNTL         5.331781      5.439322    0.02017   0.02017   2.016987
# 991:WA:SNTL         9.299419      9.889492   0.128373  0.128373  12.837282
#
#                   srho  num_obs
# site_id
# 1000:OR:SNTL       NaN      364
# 1005:CO:SNTL  0.943263      365
# 1006:NV:SNTL       NaN      363
# 1008:MT:SNTL  0.929075      365
# 1009:MT:SNTL  0.934553      365
# ...                ...      ...
# 985:WA:SNTL   0.935268      365
# 988:ID:SNTL        NaN      364
# 989:ID:SNTL   0.945064      365
# 990:WA:SNTL   0.956709      365
# 991:WA:SNTL        NaN      344
#
# [657 rows x 13 columns]

# %% [markdown]
# ### Summary plots of stats

# %%
### Absolute Relative Bias
### Good values are closer to 0.0
fig = plt.figure(figsize=(17,9), dpi=72)
plt.imshow(mask_array[::-1,:], origin='lower', cmap='Greys_r', alpha = 0.1) # CONUS2 outline 
plt.scatter(stats_df.conus2_x,stats_df.conus2_y, c=stats_df.absrelbias, s=50, vmin = 0, vmax = 1)
plt.colorbar(label='abs relative bias')
plt.axis('off')
plt.title(f'SNOTEL vs CW3E {variable} absolute relative bias, WY{water_year}')
plt.savefig(f'{plot_dir}/{summary_plot_dir}/WY{water_year}_SNOTEL_CW3E_{variable}_AbsRelBias_Map.png',\
            dpi = 200, facecolor='white', transparent=False, bbox_inches="tight")

# %%
### Relative Bias
### Good values are closer to 0.0, positive is PF overestimation, negative is PF underestimation
fig = plt.figure(figsize=(17,9), dpi=72)
plt.imshow(mask_array[::-1,:], origin='lower', cmap='Greys_r', alpha = 0.1) # CONUS2 outline 
plt.scatter(stats_df.conus2_x,stats_df.conus2_y, c=stats_df.bias, s=50, vmin = -1, vmax = 1)
plt.colorbar(label='relative bias; (+) CW3E overestimation, (-) CW3E underestimation')
plt.axis('off')
plt.title(f'SNOTEL vs CW3E {variable} relative bias, WY{water_year}')
plt.savefig(f'{plot_dir}/{summary_plot_dir}/WY{water_year}_SNOTEL_CW3E_{variable}_RelBias_Map.png',\
            dpi = 200, facecolor='white', transparent=False, bbox_inches="tight")

# %%
### Spearmsn's Rho
### Good values are closer to -1 and 1, zero is no correlation
fig = plt.figure(figsize=(19,10), dpi=72)
plt.imshow(mask_array[::-1,:], origin='lower', cmap='Greys_r', alpha = 0.1) # CONUS2 outline 
plt.scatter(stats_df.conus2_x,stats_df.conus2_y, c=stats_df.srho, s=50, vmin = -1, vmax = 1, cmap = 'coolwarm')
plt.colorbar()
plt.title(f'SNOTEL vs CW3E {variable} Srho, WY{water_year}')
plt.savefig(f'{plot_dir}/WY{water_year}_SNOTEL_CW3E_{variable}_SpearmansRho_Map.png',\
            dpi = 200, facecolor='white', transparent=False, bbox_inches="tight")

# %%
### Stations with 365 observations
all_obs = stats_df[stats_df.num_obs == 365]
print(all_obs.shape)
fig = plt.figure(figsize=(17,9), dpi=72)
plt.imshow(mask_array[::-1,:], origin='lower', cmap='Greys_r', alpha = 0.1) # CONUS2 outline 
plt.scatter(all_obs.conus2_x,all_obs.conus2_y, c=all_obs.absrelbias, cmap='cividis_r', s=55, vmax = 1)
plt.colorbar(label='Absolute Relative Bias')#label='days of recorded observations'
plt.axis('off')
plt.title(f'SNOTEL vs CW3E {variable}, complete observations (365 days), WY{water_year}')
plt.annotate(f'{len(all_obs.index)}/{len(stats_df.index)} stations',xy=(0.7,0.85), xycoords = 'axes fraction', fontsize=16)
plt.savefig(f'{plot_dir}/{summary_plot_dir}/WY{water_year}_SNOTEL_CW3E_{variable}_Complete_Observations_365.png',\
            dpi = 200, facecolor='white', transparent=False, bbox_inches="tight")
# Out:
# (291, 13)

# %%
### Stations with fewer than 365 observations
obs_threshold = 340
missed_obs = stats_df[stats_df.num_obs < obs_threshold]
print(missed_obs.shape)
fig = plt.figure(figsize=(17,9), dpi=72)
plt.imshow(mask_array[::-1,:], origin='lower', cmap='Greys_r', alpha = 0.1) # CONUS2 outline 
plt.scatter(missed_obs.conus2_x,missed_obs.conus2_y, c=missed_obs.absrelbias, cmap='cividis_r', s=55, vmax = 1)
plt.colorbar(label='Absolute Relative Bias')#label='days of recorded observations'
plt.axis('off')
plt.title(f'SNOTEL vs CW3E {variable}, incomplete observations (< {obs_threshold} days), WY{water_year}')
plt.annotate(f'{len(missed_obs.index)}/{len(stats_df.index)} stations',xy=(0.7,0.85), xycoords = 'axes fraction', fontsize=16)
plt.savefig(f'{plot_dir}/{summary_plot_dir}/SNOTEL_CW3E_{variable}_Num_Observations_{obs_threshold}.png',\
            dpi = 200, facecolor='white', transparent=False, bbox_inches="tight")
# Out:
# (77, 13)

# %% [markdown]
# ## Scatter Plots

# %%
# Scatter plot of daily mean flow for  WY2003, PF vs. USGS
fig = plt.figure(figsize=(10,10), dpi=72)
ax = fig.add_subplot()

ax.scatter(stats_df['SNOTEL_mean_T_C'], stats_df['CW3E_mean_T_C'], color='dimgray')
ax.plot(range(20), color = 'lightcoral')
plt.xlabel('SNOTEL temperature (C)',fontsize=18)
plt.ylabel('CW3E temperature (C)',fontsize=18)
plt.title(f'Daily mean temperature comparison, WY{water_year}',fontsize=20)

#ax.set_xscale('log')
#ax.set_yscale('log')
ax.xaxis.set_tick_params(labelsize=16)
ax.yaxis.set_tick_params(labelsize=16)
# square plot
ax.set_aspect('equal', adjustable='box')
plt.savefig(f'{plot_dir}/{summary_plot_dir}/SNOTEL_CW3E_meanTemp_scatter_WY{water_year}.png')

# %%
# Scatter plot of daily mean flow for  WY2003, PF vs. USGS
# Show points where we are missing observations
# Scatter plot of daily mean flow for  WY2003, PF vs. USGS
fig = plt.figure(figsize=(12,7), dpi=72)
ax = fig.add_subplot()

plt.scatter(stats_df['SNOTEL_mean_T_C'], stats_df['CW3E_mean_T_C'], c=stats_df.num_obs)
plt.colorbar(label='# days of recorded observations')
plt.plot(range(20), color = 'lightcoral')
plt.xlabel('SNOTEL temperature (C)',fontsize=18)
plt.ylabel('CW3E temperature (C)',fontsize=18)
plt.suptitle(f'Daily mean temperature comparison, WY{water_year}',fontsize=20)
plt.title('Colors indicate number of observations per SNOTEL station')

#ax.set_xscale('log')
#ax.set_yscale('log')
ax.xaxis.set_tick_params(labelsize=16)
ax.yaxis.set_tick_params(labelsize=16)
# square plot
ax.set_aspect('equal', adjustable='box')
plt.savefig(f'{plot_dir}/{summary_plot_dir}/SNOTEL_CW3E_meanTemp_scatter_WY{water_year}_num_obs.png',facecolor='white', transparent=False, bbox_inches="tight")

# %% [markdown]
# ## Make SNOTEL-CONUS2 timeseries plots
# Plot a timeseries at each station for SNOTEL Temperature observations and PF-CONUS2

# %%
### Make a plot of CONUS2 vs observed
xlength = range(len(snotel_data.columns))
xlength = [dt.datetime.strptime(d,'%Y-%m-%d').date() for d in pfdata.columns]

for i in range(len(pfdata.index)):
    gage = snotel_data.index[i]
    station_name = snotel_metadata['site_name'][gage]
    state = snotel_metadata['state'][gage]

    # make hydrographs
    fig, ax = plt.subplots(figsize=(7,5), dpi = 200)
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=3))
    #plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
    ax.plot(xlength, pfdata.loc[gage],label= 'CW3E')
    ax.plot(xlength, snotel_data.loc[gage],label= 'SNOTEL')
    #plt.gcf().autofmt_xdate()
    ax.set_ylabel('temp [C]')
    #plt.xlabel('Days')
    plt.title(f'Mean Daily Temperature - {station_name}, {state}')
    plt.annotate(f'Bias: {round(stats_df.bias.iloc[i],3)}\nSrho: {round(stats_df.srho.iloc[i],3)}',xy=(0.8,0.05), xycoords = 'axes fraction')
    ax.legend()
    #plt.savefig(f'{plot_dir}/{timeseries_plot_dir}/Timeseries_{snotel_data.index[i]}.png',facecolor='white', transparent=False, bbox_inches="tight")
    #plt.close()

# %%
#Individual Timeseries if needed
stn = 642 #row number

xlength = range(len(snotel_data.columns))
xlength = [dt.datetime.strptime(d,'%Y-%m-%d').date() for d in pfdata.columns]
gage = snotel_data.index[stn]
station_name = snotel_metadata['site_name'][gage]
print(station_name)
state = snotel_metadata['state'][gage]

fig = plt.figure(figsize=(14,10), dpi=72)
plt.plot(xlength, pfdata.loc[gage],label= 'CW3E')
plt.plot(xlength, snotel_data.loc[gage],label= 'SNOTEL')
plt.title(f'Mean Daily Temperature - {station_name}, {state}')
plt.annotate(f'Bias: {round(stats_df.bias.loc[gage],3)}\nSrho: {round(stats_df.srho.loc[gage],3)}',xy=(0.8,0.05), xycoords = 'axes fraction')
#plt.savefig(f'Jones_Pass_temperature_{water_year}.png', facecolor='white', transparent=False, bbox_inches="tight")
# Out:
# Columbus Basin
# Text(0.8, 0.05, 'Bias: 0.392\nSrho: 0.939')
